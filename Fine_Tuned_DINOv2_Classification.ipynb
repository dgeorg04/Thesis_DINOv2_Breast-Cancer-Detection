# %%
 # Imports for data manipulation, processing, data loading, visualization and other utility imports
import torch
import torchvision.transforms as T
import torch.nn as nn
import torch.optim as optim
from torchvision import models
from sklearn.metrics import accuracy_score
import numpy as np
from sklearn.decomposition import PCA
from torchvision import transforms
import sklearn
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
from sklearn.model_selection import StratifiedKFold
import shutil
import os
from torch.nn import functional as F

# %%
import os

# Defining the folder paths for both healthy and sick images
base_path = "/content/drive/MyDrive/Dataset/newdb"
healthy_path = os.path.join(base_path, "Healthy")
sick_path = os.path.join(base_path, "Unhealthy")
subfolders = [healthy_path, sick_path]

# %%
#Reading the images
# Get all image file paths from Healthy and Sick directories
healthy_images = [os.path.join(healthy_path, fname) for fname in os.listdir(healthy_path) if fname.lower().endswith(('jpg'))]
sick_images = [os.path.join(sick_path, fname) for fname in os.listdir(sick_path) if fname.lower().endswith(('jpg'))]

# Combine them into a single list with labels
img_paths = healthy_images + sick_images
img_labels = ['Healthy'] * len(healthy_images) + ['Unhealthy'] * len(sick_images)

# Print some examples to confirm
print("First 5 Healthy Images:", healthy_images[:5])
print("First 5 Sick Images:", sick_images[:5])
print("Number of images:", len(img_paths))
# Out:
# First 5 Healthy Images: ['/content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0092_anterior.jpg', '/content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0094_anterior.jpg', '/content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0055_anterior.jpg', '/content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0042_anterior.jpg', '/content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0074_anterior.jpg']
# First 5 Sick Images: ['/content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0296_anterior.jpg', '/content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0326_anterior.jpg', '/content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0328_anterior.jpg', '/content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0307_anterior.jpg', '/content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0299_anterior.jpg']
# Number of images: 142

# %%
##### EXPERIMENT PARAMETERS #####
# Constants to control grid size
N_IMGS = len(img_paths)  # Total number of valid images
N_ROW_IMGS = 4  # Number of rows in the grid
N_COL_IMGS = (N_IMGS + N_ROW_IMGS - 1) // N_ROW_IMGS  # Calculate columns dynamically



# Define the number of patches along the two dimensions to split each image into
patch_h = 32
patch_w = 32
# Define the size of the model to use for extracting the features of each patch
model_size = 's' # options: s, b, l, g
use_registers = False
use_extended_dinov2 = True

patch_multiplier = 7  # Multiplier for patch count (to get 224x224 from 32x32 patches)

# Define the final image size (this will be calculated dynamically based on patches)
final_size = patch_h * patch_multiplier  # final image size will be 32 * 7 = 224
print(f"Final image size: {final_size}x{final_size}")
print(N_IMGS)
# Out:
# Final image size: 224x224
# 142

# %%
#Preprocessing and Colorization
from PIL import Image
#define the output directory for transformed images
output_dir = "/content/drive/MyDrive/Dataset/DINOv2_images"
os.makedirs(output_dir, exist_ok=True)  # Create folder if it doesn't exist

#define DINOv2-compatible transformations
dinov2_transform = transforms.Compose([
    transforms.Resize((224, 224)),  # Resize to 224x224
    transforms.ToTensor(),  # Convert image to tensor (C, H, W)
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],  # Normalize using ImageNet values
        std=[0.229, 0.224, 0.225]
    )
])

#initialize tensor to store transformed images for DINOv2
imgs_tensor = torch.zeros(len(img_paths), 3, 224, 224)  # (N, C, H, W)

#function to process image (Colorize + DINOv2 Transform) and save it as ONE file
def process_image(image_path, index):
    # Open and convert to grayscale
    img = Image.open(image_path).convert("L")
    img_np = np.array(img)

    #apply JET colormap
    img_color = cv2.applyColorMap(img_np, cv2.COLORMAP_JET)
    colorized_img = Image.fromarray(img_color)  # Convert to PIL format

    #apply DINOv2 transformations
    img_tensor = dinov2_transform(colorized_img)
    imgs_tensor[index] = img_tensor  # Store the transformed tensor

    #convert the tensor back to a displayable image
    img_numpy = img_tensor.permute(1, 2, 0).mul(torch.tensor([0.229, 0.224, 0.225])).add(torch.tensor([0.485, 0.456, 0.406]))  # Undo normalization
    img_numpy = torch.clamp(img_numpy, 0, 1).cpu().numpy()  # Ensure values are in range [0,1]
    img_resized = Image.fromarray((img_numpy * 255).astype(np.uint8))  # Convert to 8-bit image

    #generate new filename and save the transformed image in the DINOv2 folder
    base_name = os.path.basename(image_path).split('.')[0]
    dinov2_path = os.path.join(output_dir, f"{base_name}_DINOv2.jpg")
    img_resized.save(dinov2_path)

    return dinov2_path  # Return the saved image path

#process all images
for i, img_path in enumerate(img_paths):
    print(f"Processing {img_path}...")
    dinov2_image_path = process_image(img_path, i)

print("All images have been **colorized, transformed, and saved** in 'DINOv2_images'.")
print("Final dataset tensor shape:", imgs_tensor.shape)  # Should be (N, 3, 224, 224)

#extra step to check ** (optional)
for path in os.listdir(output_dir):
    full_path = os.path.join(output_dir, path)
    img = Image.open(full_path)
    if img.size != (224, 224):
        print(f"Not resized: {full_path} | Size: {img.size}")
# Out:
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0092_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0094_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0055_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0042_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0074_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0066_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0083_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0077_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0045_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0082_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0103_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0090_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0061_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0080_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0068_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0064_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0091_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0088_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0049_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0057_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0076_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0105_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0060_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0099_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0023_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0041_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0022_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0044_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0014_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0040_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0021_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0016_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0053_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0018_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0051_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0013_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0058_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0029_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0037_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0047_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0027_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0073_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0078_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0017_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0015_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0054_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0067_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0079_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0026_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0025_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0075_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0012_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0010_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0039_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0001_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0095_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0004_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0007_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0011_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0032_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0033_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0031_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0008_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0003_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0009_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0028_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0005_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0020_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0002_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0006_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Healthy/IIR0034_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0296_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0326_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0328_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0307_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0299_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0327_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0314_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0302_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0096_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0323_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0317_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0298_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0322_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0320_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0321_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0324_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0293_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0316_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0301_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0318_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0294_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0310_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0325_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0315_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0300_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0305_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0295_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0304_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0319_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0303_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0309_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0297_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0063_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0050_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0043_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0036_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0312_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0062_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0046_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0071_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0024_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0070_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0098_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0085_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0086_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0038_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0069_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0030_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0329_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0048_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0311_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0059_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0035_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0104_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0065_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0089_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0019_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0100_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0102_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0056_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0081_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0313_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0052_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0101_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0308_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0087_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0072_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0084_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0119_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0097_anterior.jpg...
# Processing /content/drive/MyDrive/Dataset/newdbBalanced/Unhealthy/IIR0093_anterior.jpg...
# All images have been **colorized, transformed, and saved** in 'DINOv2_images'.
# Final dataset tensor shape: torch.Size([142, 3, 224, 224])

# %%
# #Show the images selected
# # List to store valid image paths
# img_paths = []

# # Iterate through subfolders and image numbers
# for subfolder in subfolders:
#     folder_path = os.path.join(base_path, subfolder)
#     for i in range(1, 329):  # Iterate from 1 to 372
#         # Construct the image filename
#         image_name = f"IIR{i:04d}_anterior.jpg"  # Format number with leading zeros
#         image_path = os.path.join(folder_path, image_name)

#         # Check if the file exists
#         if os.path.isfile(image_path):
#             img_paths.append(image_path)


# # Function to display the images
# def plot_original_images():
#     plt.figure(figsize=(2 * N_COL_IMGS, 2 * N_ROW_IMGS), dpi=120)
#     for i in range(N_IMGS-1):
#         plt.subplot(N_ROW_IMGS, N_COL_IMGS, i + 1)
#         plt.xticks([])
#         plt.yticks([])
#         # Read and display the image from the local path
#         plt.imshow(mpimg.imread(img_paths[i]))
#         plt.title(f"Image {i+1}")  # Optional: Add titles for clarity
#     plt.tight_layout()
#     plt.show()
#     plt.close()

# # Call the function to display the images
# plot_original_images()

# %%
#Splitting the Dataset (into training, validation and testing set) using StratifiedKFolds
#imports and configuration
import os
import torch
import numpy as np
from sklearn.model_selection import StratifiedKFold, train_test_split
import shutil


#number of k folds to use
n_splits = 5
#folder paths for saving split data and transformed images
output_folder = "/content/drive/MyDrive/Dataset/Split_Folds"
dinov2_images_dir = "/content/drive/MyDrive/Dataset/DINOv2_images"
os.makedirs(output_folder, exist_ok=True)

#check if the folds already exist
folds = []
found_all_folds = True

#try loading all 5 pre-saved fold files
for fold in range(1, n_splits + 1):
    fold_path = os.path.join(output_folder, f"dinov2_fold_{fold}.pt")
    if os.path.exists(fold_path):
        print(f"Fold {fold} found. Loading from file.")
        fold_data = torch.load(fold_path, weights_only=False)
        folds.append(fold_data)
    else:
        print(f"Fold {fold} not found. Will re-run data splitting.")
        found_all_folds = False
        break

#print the class distribution of the existing folds
if found_all_folds:
    print("\nLoaded Fold Stats:")

    for i, fold in enumerate(folds):
        print(f"\nFold {i + 1} - Dataset Breakdown:")

        for split_name, labels in {
            "Train": fold["y_train"],
            "Validate-Test": fold["y_test"],
            "Final Test": fold["y_final"]
        }.items():
            total = len(labels)
            healthy = sum(1 for label in labels if label == "Healthy")
            unhealthy = sum(1 for label in labels if label == "Unhealthy")
            print(f"  {split_name}: {total} images ({healthy} Healthy, {unhealthy} Unhealthy)")


#if any of the folds isn't foundm run stratified k-fold splitting
if not found_all_folds:
    print("\nRe-running StratifiedKFold splitting and saving folds...")

    labels = np.array(img_labels)   # labels as NumPy array
    all_indices = np.arange(len(imgs_tensor)) #original indices for tracking

    #split into 80% train/test and 20% final test and track the original indices
    X_train_test, X_final, y_train_test, y_final, train_test_indices, final_indices = train_test_split(
        imgs_tensor, labels, all_indices, test_size=0.20, stratify=labels, shuffle=True, random_state=42
    )

    print(f"\nAfter split: {X_train_test.shape[0]} train/test, {X_final.shape[0]} final test")

    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

    for fold, (train_index, test_index) in enumerate(skf.split(X_train_test, y_train_test)):
        X_train, X_test = X_train_test[train_index], X_train_test[test_index]
        y_train, y_test = y_train_test[train_index], y_train_test[test_index]

        # create the fold dictionary
        fold_data = {
            "X_train": X_train, "y_train": y_train,
            "X_test": X_test, "y_test": y_test,
            "X_final": X_final, "y_final": y_final, #final set shared across all folds
        }
        folds.append(fold_data)

        #save the newly created fold
        fold_path = os.path.join(output_folder, f"dinov2_fold_{fold + 1}.pt")
        torch.save(fold_data, fold_path)
        print(f"Saved fold {fold + 1} -> {fold_path}")

        split_images_root = os.path.join(output_folder, "SPLITS", f"fold_{fold + 1}")
        os.makedirs(split_images_root, exist_ok=True)

        #map split names to indices and labels
        split_mapping = {
            "Train": (train_index, y_train),
            "Validate-Test": (test_index, y_test),
            "Final Test": (final_indices, y_final)
        }

        print(f"\n Fold {fold + 1} - Dataset Breakdown:")

        for split_name, (indices, y_labels) in split_mapping.items():
            split_folder = os.path.join(split_images_root, split_name)
            os.makedirs(split_folder, exist_ok=True)

            #print split summary
            total = len(indices)
            healthy = sum(1 for label in y_labels if label == "Healthy")
            unhealthy = sum(1 for label in y_labels if label == "Unhealthy")
            print(f"  {split_name}: {total} images ({healthy} Healthy, {unhealthy} Unhealthy)")

            #copy image files into the appropriate split folder
            for idx in indices:
                original_index = idx if split_name == "Final Test" else train_test_indices[idx]

                orig_img_path = img_paths[original_index]
                base_name = os.path.basename(orig_img_path).split('.')[0]
                transformed_name = f"{base_name}_DINOv2.jpg"
                transformed_path = os.path.join(dinov2_images_dir, transformed_name)

                if os.path.exists(transformed_path):
                    shutil.copy(transformed_path, os.path.join(split_folder, transformed_name))
                else:
                    print(f"Missing transformed image: {transformed_path}")
# Out:
# Fold 1 not found. Will re-run data splitting.
#
# Re-running StratifiedKFold splitting and saving folds...
#
# After split: 113 train/test, 29 final test
# Saved fold 1 -> /content/drive/MyDrive/Dataset/Split_FoldsBalanced/dinov2_fold_1.pt
#
#  Fold 1 - Dataset Breakdown:
#   Train: 90 images (45 Healthy, 45 Unhealthy)
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0022_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0002_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0093_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0098_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0065_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0061_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0089_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0077_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0101_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0064_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0013_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0018_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0295_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0091_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0038_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0044_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0004_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0078_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0104_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0096_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0080_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0299_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0298_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0021_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0045_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0051_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0095_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0294_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0088_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0016_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0074_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0006_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0324_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0001_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0320_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0090_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0011_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0317_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0041_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0302_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0307_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0097_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0072_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0308_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0327_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0032_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0053_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0312_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0062_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0073_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0050_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0092_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0037_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0082_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0070_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0328_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0023_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0085_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0081_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0014_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0059_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0042_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0329_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0067_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0100_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0025_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0303_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0325_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0075_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0060_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0102_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0019_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0063_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0057_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0304_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0293_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0316_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0297_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0083_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0054_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0309_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0326_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0318_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0027_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0031_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0034_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0079_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0039_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0314_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0311_anterior_DINOv2.jpg
#   Validate-Test: 23 images (11 Healthy, 12 Unhealthy)
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0043_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0087_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0066_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0009_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0103_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0048_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0007_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0296_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0047_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0322_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0046_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0310_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0301_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0026_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0069_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0323_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0084_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0028_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0049_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0003_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0036_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0058_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0015_anterior_DINOv2.jpg
#   Final Test: 29 images (15 Healthy, 14 Unhealthy)
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0086_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0055_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0305_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0094_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0056_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0033_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0321_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0300_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0099_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0005_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0010_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0040_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0068_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0012_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0029_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0315_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0105_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0119_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0017_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0076_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0313_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0020_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0008_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0024_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0052_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0035_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0030_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0071_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0319_anterior_DINOv2.jpg
# Saved fold 2 -> /content/drive/MyDrive/Dataset/Split_FoldsBalanced/dinov2_fold_2.pt
#
#  Fold 2 - Dataset Breakdown:
#   Train: 90 images (45 Healthy, 45 Unhealthy)
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0043_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0087_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0022_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0002_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0093_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0066_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0065_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0061_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0089_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0077_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0101_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0013_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0009_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0295_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0103_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0091_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0038_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0044_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0004_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0078_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0096_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0080_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0048_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0299_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0298_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0007_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0051_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0296_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0047_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0095_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0088_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR
Unhealthy)
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0043_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0087_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0022_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0093_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0098_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0066_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0065_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0061_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0077_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0101_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0064_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0013_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0018_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0009_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0295_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0103_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0091_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0038_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0004_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0104_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0048_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0299_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0298_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0021_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0007_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0045_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0296_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0047_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0294_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0088_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0322_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0016_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0074_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0006_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0046_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0324_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0001_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0320_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0090_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0011_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0317_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0041_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0307_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0072_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0310_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0308_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0327_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0032_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0053_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0312_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0073_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0037_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0082_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0070_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0301_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0328_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0059_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0026_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0042_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0329_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0067_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0069_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0100_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0323_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0025_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0303_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0325_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0075_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0102_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0019_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0057_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0084_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0028_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0304_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0293_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0049_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0297_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0003_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0083_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0036_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0054_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0309_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0326_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0318_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0027_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0031_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0034_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0058_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0039_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0311_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0015_anterior_DINOv2.jpg
#   Validate-Test: 22 images (11 Healthy, 11 Unhealthy)
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0002_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0089_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0044_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0078_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0096_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0080_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0051_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0095_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0302_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0097_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0062_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0050_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0092_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0023_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0085_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0081_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0014_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0060_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0063_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0316_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0079_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0314_anterior_DINOv2.jpg
#   Final Test: 29 images (15 Healthy, 14 Unhealthy)
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0086_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0055_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0305_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0094_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0056_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0033_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0321_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0300_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0099_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0005_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0010_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0040_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0068_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0012_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0029_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0315_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0105_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0119_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0017_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0076_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0313_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0020_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0008_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0024_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0052_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0035_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0030_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0071_anterior_DINOv2.jpg
# Missing transformed image: /content/drive/MyDrive/Dataset/DINOv2_imagesBalanced/IIR0319_anterior_DINOv2.jpg

# %%
#Mount the drive content
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path='/content/drive/MyDrive/neco_on_dinov2r_vit14_model.ckpt'
# !ls /content/drive/MyDrive/neco_on_dinov2r_vit14_model.ckpt
# Out:
# /content/drive/MyDrive/neco_on_dinov2r_vit14_model.ckpt

# %%
# Instructions:
# From https://github.com/vpariza/NeCo?tab=readme-ov-file download the student Dinov2 ViT-S/14 from  https://1drv.ms/u/c/67fac29a77adbae6/EWvXdau9r6NIr-vIc_xDlxAB1sDrljoaPR_A3JhIEeE8dw?e=pOXEXG
# upload to google drive
# and find the path to the file on google drive
path = "/content/drive/MyDrive/neco_on_dinov2r_vit14_model.ckpt"
# !ls /content/drive/MyDrive/neco_on_dinov2r_vit14_model.ckpt
# Out:
# /content/drive/MyDrive/neco_on_dinov2r_vit14_model.ckpt

# %%
#load the small model
#import torch #Import the torch library
model = torch.hub.load('facebookresearch/dinov2', 'dinov2_vits14')
model.load_state_=dict(torch.load(path), strict=False)
# Out:
# Downloading: "https://github.com/facebookresearch/dinov2/zipball/main" to /root/.cache/torch/hub/main.zip
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/swiglu_ffn.py:51: UserWarning: xFormers is not available (SwiGLU)
#   warnings.warn("xFormers is not available (SwiGLU)")
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/attention.py:33: UserWarning: xFormers is not available (Attention)
#   warnings.warn("xFormers is not available (Attention)")
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/block.py:40: UserWarning: xFormers is not available (Block)
#   warnings.warn("xFormers is not available (Block)")
# Downloading: "https://dl.fbaipublicfiles.com/dinov2/dinov2_vits14/dinov2_vits14_pretrain.pth" to /root/.cache/torch/hub/checkpoints/dinov2_vits14_pretrain.pth
# 100%|██████████| 84.2M/84.2M [00:00<00:00, 289MB/s]

# %%
print(model)
# Out:
# DinoVisionTransformer(
#   (patch_embed): PatchEmbed(
#     (proj): Conv2d(3, 384, kernel_size=(14, 14), stride=(14, 14))
#     (norm): Identity()
#   )
#   (blocks): ModuleList(
#     (0-11): 12 x NestedTensorBlock(
#       (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (attn): MemEffAttention(
#         (qkv): Linear(in_features=384, out_features=1152, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): LayerScale()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=384, out_features=1536, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=1536, out_features=384, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): LayerScale()
#       (drop_path2): Identity()
#     )
#   )
#   (norm): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#   (head): Identity()
# )

# %%
#feature extraction using dinov2
#tensor = torch.randn(N_IMGS, 3, 224, 224) # 16*14 =224

#use preprocessed image tensor (already normalized, resized to 224x224)
#shape must be [N, 3 channels, 224, 224]
tensor=imgs_tensor
display(tensor.shape)

#load dinov2 from torchhub
#depending on configuration, load DINOv2 ViT model with or without registers
if use_registers:
  model = torch.hub.load('facebookresearch/dinov2', 'dinov2_vit{}14_reg'.format(model_size))
else:
  model = torch.hub.load('facebookresearch/dinov2', 'dinov2_vit{}14'.format(model_size))
#forward pass: get dictionary of intermediate features
features_dict = model.forward_features(tensor)
#display available keys in the feature dictionary
display(features_dict.keys())
#show the shape of each important feature tensor
display(features_dict['x_norm_clstoken'].shape)
display(features_dict['x_norm_regtokens'].shape)
display(features_dict['x_norm_patchtokens'].shape)
display(features_dict['x_prenorm'].shape)


#print the final name of the model used to see if its with registers
model_name = f'dinov2_vit{model_size}14' + ('_reg' if use_registers else '')
print("Loaded model:", model_name)
# Out:
# torch.Size([142, 3, 224, 224])
# Using cache found in /root/.cache/torch/hub/facebookresearch_dinov2_main
# dict_keys(['x_norm_clstoken', 'x_norm_regtokens', 'x_norm_patchtokens', 'x_prenorm', 'masks'])
# torch.Size([142, 384])
# torch.Size([142, 0, 384])
# torch.Size([142, 256, 384])
# torch.Size([142, 257, 384])
# Loaded model: dinov2_vits14

# %%
# select feature dimensions based on the model used
feat_dims = {
    's': 384,    # ViT-S/14 small
    'b': 768,    # ViT-B/14 base
    'l': 1024,   # ViT-L/14 large
    'g': 1536,   # ViT-G/14 giant
}
feat_dim = feat_dims[model_size]  # model_size = 's', 'b', 'l', or 'g'

# Transform (only normalize because images are already resized & colorized)
dinov2_transform = T.Compose([
    T.ToTensor(),
    T.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))
])

# load the dinov2 model with or without registers
if use_registers:
    model = torch.hub.load('facebookresearch/dinov2', f'dinov2_vit{model_size}14_reg')
else:
    model = torch.hub.load('facebookresearch/dinov2', f'dinov2_vit{model_size}14')

if not use_extended_dinov2:
    model.load_state_dict(torch.load(path), strict=False)

#load the transformed image paths
dinov2_img_paths = [
    os.path.join("/content/drive/MyDrive/Dataset/DINOv2_images", os.path.basename(p).split('.')[0] + "_DINOv2.jpg")
    for p in img_paths
]

#load and normalize images
N_IMGS = len(dinov2_img_paths)
imgs_tensor = torch.zeros(N_IMGS, 3, 224, 224)

for i, path in enumerate(dinov2_img_paths):
    img = Image.open(path).convert("RGB")
    img_tensor = dinov2_transform(img)

    #check for safety
    if img_tensor.shape != (3, 224, 224):
        print(f"Shape mismatch: {path} | Got: {img_tensor.shape}")
    else:
        print(f"Loaded and normalized: {path}")

    imgs_tensor[i] = img_tensor

#move to device and extract [CLS] features
with torch.no_grad():
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = model.to(device)
    imgs_tensor = imgs_tensor.to(device)

    features_dict = model.forward_features(imgs_tensor)
    cls_features = features_dict['x_norm_clstoken'].cpu()  # This is your [CLS] token

#check
print(f" Extracted [CLS] features | Shape: {cls_features.shape}")
# Out:
# Using cache found in /root/.cache/torch/hub/facebookresearch_dinov2_main
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0092_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0094_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0055_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0042_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0074_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0066_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0083_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0077_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0045_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0082_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0103_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0090_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0061_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0080_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0068_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0064_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0091_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0088_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0049_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0057_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0076_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0105_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0060_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0099_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0023_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0041_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0022_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0044_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0014_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0040_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0021_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0016_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0053_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0018_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0051_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0013_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0058_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0029_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0037_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0047_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0027_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0073_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0078_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0017_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0015_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0054_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0067_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0079_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0026_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0025_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0075_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0012_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0010_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0039_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0001_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0095_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0004_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0007_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0011_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0032_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0033_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0031_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0008_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0003_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0009_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0028_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0005_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0020_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0002_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0006_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0034_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0296_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0326_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0328_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0307_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0299_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0327_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0314_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0302_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0096_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0323_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0317_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0298_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0322_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0320_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0321_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0324_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0293_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0316_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0301_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0318_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0294_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0310_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0325_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0315_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0300_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0305_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0295_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0304_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0319_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0303_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0309_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0297_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0063_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0050_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0043_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0036_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0312_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0062_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0046_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0071_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0024_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0070_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0098_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0085_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0086_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0038_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0069_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0030_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0329_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0048_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0311_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0059_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0035_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0104_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0065_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0089_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0019_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0100_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0102_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0056_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0081_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0313_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0052_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0101_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0308_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0087_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0072_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0084_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0119_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0097_anterior_DINOv2.jpg
# Loaded and normalized: /content/drive/MyDrive/Dataset/DINOv2_imagesBALANCED/IIR0093_anterior_DINOv2.jpg
#  Extracted [CLS] features | Shape: torch.Size([142, 384])

# %%
# !nvidia-smi

# %%
# # Apply PCA on the features of each patch across all the images in our set
# features = features.reshape(N_IMGS * patch_h * patch_w, feat_dim)
# print('Features Shape: ',features.shape)
# pca = PCA(n_components=3)
# pca.fit(features)
# pca_features = pca.transform(features)

# %%
# # visualize PCA components for finding a proper threshold
# plt.subplot(1, 3, 1)
# plt.hist(pca_features[:, 0])
# plt.subplot(1, 3, 2)
# plt.hist(pca_features[:, 1])
# plt.subplot(1, 3, 3)
# plt.hist(pca_features[:, 2])
# plt.show()
# plt.close()

# %%
# minmax_scale = lambda pca_features: (pca_features - pca_features.min()) / (pca_features.max() - pca_features.min())

# %%
# # visualize PCA components for finding a proper threshold
# plt.subplot(1, 3, 1)
# plt.hist(minmax_scale(pca_features[:, 0]))
# plt.subplot(1, 3, 2)
# plt.hist(minmax_scale(pca_features[:, 1]))
# plt.subplot(1, 3, 3)
# plt.hist(minmax_scale(pca_features[:, 2]))
# plt.show()
# plt.close()

# %%
# # The threshold to be used for separating the foreground from the background,
# # using the major PCA component (i.e., the first one at position 0) of each
# # patch
# PCA_THRESHOLD = 10
# PCA_THRESHOLD_RATIO = 0.6

# %%
# # plot the first pca component
# # Min - Max normalization of first PCA component for all images
# pca_features_norm = pca_features.copy()
# pca_features_norm[:, 0] = minmax_scale(pca_features_norm[:, 0])

# plt.figure(figsize=(2 * (N_IMGS / N_ROW_IMGS), 2 * (N_IMGS / N_COL_IMGS)), dpi=80)
# for i in range(N_IMGS):
#     # plot the first pca component for eacg image
#     plt.subplot(N_ROW_IMGS, N_COL_IMGS, i+1)
#     plt.xticks([])
#     plt.yticks([])
#     plt.imshow(pca_features_norm[i * patch_h * patch_w: (i+1) * patch_h * patch_w, 0].reshape(patch_h, patch_w))
# plt.show()
# plt.close()

# %%
# ######## APPROACH 1 ########
# # Threshold with an absolute value

# # segment foreground from background using the first component
# # Background identified by the components below the threshold
# # pca_features_bg_mask = pca_features[:, 0] < PCA_THRESHOLD
# # # Foreground identified by the components above the threshold
# # pca_features_fg_mask = ~pca_features_bg_mask

# ######## APPROACH 2 ########
# # Threshold with an absolute value from the normalized values

# # segment foreground from background using the first component
# # Background identified by the components below the threshold
# pca_features_bg_mask = pca_features_norm[:, 0] < PCA_THRESHOLD_RATIO
# # Foreground identified by the components above the threshold
# pca_features_fg_mask = ~pca_features_bg_mask

# %%
# # plot the background using the pca_features_bg
# plt.figure(figsize=(2 * (N_IMGS / N_ROW_IMGS), 2 * (N_IMGS / N_COL_IMGS)), dpi=80)
# for i in range(N_IMGS):
#     plt.subplot(N_ROW_IMGS, N_COL_IMGS, i+1)
#     plt.xticks([])
#     plt.yticks([])
#     plt.imshow(pca_features_bg_mask[i * patch_h * patch_w: (i+1) * patch_h * patch_w].reshape(patch_h, patch_w))
# plt.show()

# %%
# # plot the background using the pca_features_bg
# plt.figure(figsize=(2 * (N_IMGS / N_ROW_IMGS), 2 * (N_IMGS / N_COL_IMGS)), dpi=80)
# for i in range(N_IMGS):
#     plt.subplot(N_ROW_IMGS, N_COL_IMGS, i+1)
#     plt.xticks([])
#     plt.yticks([])
#     mask = pca_features_bg_mask[i * patch_h * patch_w: (i+1) * patch_h * patch_w].reshape(patch_h, patch_w)
#     mask = np.repeat(np.expand_dims(mask,axis=-1),3,axis=-1)
#     c = np.zeros((patch_h, patch_w,3))
#     c[:,:,0] = 1.0

#     img = np.where(mask, np.zeros((patch_h, patch_w,3)), c)
#     plt.imshow(img)
# plt.show()

# %%
# # PCA for only foreground patches
# pca.fit(features[pca_features_fg_mask])
# pca_features_rem = pca.transform(features[pca_features_fg_mask])

# for i in range(3):
#     # pca_features_rem[:, i] = (pca_features_rem[:, i] - pca_features_rem[:, i].min()) / (pca_features_rem[:, i].max() - pca_features_rem[:, i].min())
#     # transform using mean and std, I personally, this transformation seems to give a better visualization
#     pca_features_rem[:, i] = (pca_features_rem[:, i] - pca_features_rem[:, i].mean()) / (pca_features_rem[:, i].std() ** 2) + 0.5

# pca_features_rgb = pca_features.copy()
# pca_features_rgb[pca_features_bg_mask] = 0
# pca_features_rgb[pca_features_fg_mask] = pca_features_rem

# pca_features_rgb = pca_features_rgb.reshape(N_IMGS, patch_h, patch_w, 3)
# plt.figure(figsize=(2 * (N_IMGS / N_ROW_IMGS), 2 * (N_IMGS / N_COL_IMGS)), dpi=80)
# for i in range(N_IMGS):
#     plt.subplot(N_ROW_IMGS, N_COL_IMGS, i+1)
#     plt.xticks([])
#     plt.yticks([])
#     plt.imshow(pca_features_rgb[i][..., ::-1])
# plt.savefig('features.png')
# plt.show()
# plt.close()

# %%
#Pure Linear HEAD https://github.com/NielsRogge/Transformers-Tutorials/blob/master/DINOv2/Train_a_linear_classifier_on_top_of_DINOv2_for_semantic_segmentation.ipynb?fbclid=IwY2xjawIq_NxleHRuA2FlbQIxMAABHaJ21bD3gYnAURGck-pM06xz8sNKEeC8JOTbOeSpow2dO99Qww8he1Fz1Q_aem_ZWCgSLLZnJld1lOzhsJ3Qw
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, f1_score
import numpy as np
import os
from sklearn.preprocessing import StandardScaler
import glob


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

#labeling the healthy and unhealthy class to numerical values
label_mapping = {"Healthy": 0, "Unhealthy": 1}
folds_folder = "/content/drive/MyDrive/Dataset/Split_Folds"

#freeze the entire model
for param in model.parameters():
    param.requires_grad = False

#define and attach linear head
num_features = model.norm.weight.shape[0]
model.fc = nn.Linear(num_features, 1).to(device)

#loop through each fold
for fold in range(1, 6):
    print(f"\n Fold {fold}")

    fold_path = os.path.join(folds_folder, f"dinov2_fold_{fold}.pt")
    data = torch.load(fold_path, weights_only=False)
    final_test_folder = os.path.join("/content/drive/MyDrive/Dataset/Split_Folds/SPLITS", f"fold_{fold}", "Final Test")
    final_filenames = sorted([os.path.basename(f) for f in glob.glob(os.path.join(final_test_folder, "*"))])

    #prepare list to collect misclassified samples
    misclassified_final_samples = []

    def encode_labels(y):
        return torch.tensor([label_mapping[label] for label in y], dtype=torch.float32)

    X_train = data["X_train"].to(device)
    y_train = encode_labels(data["y_train"]).to(device)
    X_test = data["X_test"].to(device)
    y_test = encode_labels(data["y_test"]).to(device)
    X_final = data["X_final"].to(device)
    y_final = encode_labels(data["y_final"]).to(device)

    #feature extraction with debugging
    try:
        print("Extracting DINOv2 features...")
        with torch.no_grad():
            scaler = StandardScaler()

            f_train = model.forward_features(X_train)["x_norm_clstoken"]
            f_test = model.forward_features(X_test)["x_norm_clstoken"]
            f_final = model.forward_features(X_final)["x_norm_clstoken"]

            f_train = scaler.fit_transform(f_train.cpu())
            f_test = scaler.transform(f_test.cpu())
            f_final = scaler.transform(f_final.cpu())

            f_train = torch.tensor(f_train, device=device).float()
            f_test = torch.tensor(f_test, device=device).float()
            f_final = torch.tensor(f_final, device=device).float()

        print("Feature extraction successful.")
    except Exception as e:
        print(f"Feature extraction failed: {e}")
        continue

    #prepare data loaders of each set
    train_loader = DataLoader(TensorDataset(f_train, y_train), batch_size=32, shuffle=True)
    test_loader = DataLoader(TensorDataset(f_test, y_test), batch_size=32)
    final_loader = DataLoader(TensorDataset(f_final, y_final), batch_size=32)

    #loss & optimizer
    pos_weight = torch.tensor([1.35], device=device)
    criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight)
    optimizer = optim.AdamW(model.fc.parameters(), lr=1e-3)

    #training loop
    n_epochs = 50
    for epoch in range(n_epochs):

        #train
        model.fc.train()
        train_loss = 0.0
        train_preds_raw, train_labels_list = [], []

        for features, labels in train_loader:
            optimizer.zero_grad()
            outputs = model.fc(features).squeeze(1)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            train_loss += loss.item()
            train_preds_raw.extend(outputs.detach().cpu().numpy())
            train_labels_list.extend(labels.cpu().numpy())

        #validate
        model.fc.eval()
        val_preds_raw, val_labels_list = [], []

        with torch.no_grad():
            for features, labels in test_loader:
                outputs = model.fc(features).squeeze(1)
                val_preds_raw.extend(outputs.cpu().numpy())
                val_labels_list.extend(labels.cpu().numpy())

        fpr, tpr, thresholds = roc_curve(val_labels_list, val_preds_raw)
        high_sens_mask = tpr >= 0.90
        candidate_thresholds = thresholds[high_sens_mask]

        if candidate_thresholds.size > 0:
            f1_scores = []
            for i, thresh in enumerate(candidate_thresholds):
                preds = (np.array(val_preds_raw) > thresh).astype(int)
                if (tpr[high_sens_mask][i] >= 0.90):
                    f1_scores.append(f1_score(val_labels_list, preds))
                else:
                    f1_scores.append(0)
            best_thresh = candidate_thresholds[np.argmax(f1_scores)]
        else:
            print("No threshold satisfies sensitivity ≥ 0.90 — using 0.5 fallback.")
            best_thresh = 0.5

        #metrics: Training
        train_preds = (np.array(train_preds_raw) > best_thresh).astype(int)
        train_acc = accuracy_score(train_labels_list, train_preds)
        tn, fp, fn, tp = confusion_matrix(train_labels_list, train_preds).ravel()
        train_sens = tp / (tp + fn) if (tp + fn) > 0 else 0
        train_spec = tn / (tn + fp) if (tn + fp) > 0 else 0
        train_f1 = f1_score(train_labels_list, train_preds)

        #metrics: Validation
        val_preds = (np.array(val_preds_raw) > best_thresh).astype(int)
        val_acc = accuracy_score(val_labels_list, val_preds)
        tn, fp, fn, tp = confusion_matrix(val_labels_list, val_preds).ravel()
        val_sens = tp / (tp + fn) if (tp + fn) > 0 else 0
        val_spec = tn / (tn + fp) if (tn + fp) > 0 else 0
        val_f1 = f1_score(val_labels_list, val_preds)

             #validation loss
        validation_loss = 0.0
        with torch.no_grad():
            for features, labels in test_loader:
                outputs = model.fc(features).squeeze(1)
                loss = criterion(outputs, labels)
                validation_loss += loss.item()
        validation_loss /= len(test_loader)


        #metrics: Final Test
        final_preds_raw, final_labels = [], []
        test_loss = 0.0
        with torch.no_grad():
            for features, labels in final_loader:
                outputs = model.fc(features).squeeze(1)
                final_preds_raw.extend(outputs.cpu().numpy())
                final_labels.extend(labels.cpu().numpy())
                loss = criterion(outputs, labels)
                test_loss += loss.item()
        test_loss /= len(final_loader)

        final_preds = (np.array(final_preds_raw) > best_thresh).astype(int)
        final_acc = accuracy_score(final_labels, final_preds)
        tn, fp, fn, tp = confusion_matrix(final_labels, final_preds).ravel()
        final_sens = tp / (tp + fn) if (tp + fn) > 0 else 0
        final_spec = tn / (tn + fp) if (tn + fp) > 0 else 0
        final_f1 = f1_score(final_labels, final_preds)
        #debug
        #print(f"Fold {fold}: {len(final_preds)} predictions vs {len(final_filenames)} filenames")
        #identify and print misclassified final test images
        for global_idx, (pred, label) in enumerate(zip(final_preds, final_labels)):
         if pred != label:
            filename = final_filenames[global_idx]
            misclassified_final_samples.append((fold, epoch+1, filename, int(label), int(pred)))


        #epoch summary
        print(f"Epoch {epoch+1}/{n_epochs} | "
      f"Train | Loss: {train_loss:.4f} | Acc: {train_acc:.4f} | Sens: {train_sens:.4f} | Spec: {train_spec:.4f} | F1: {train_f1:.4f} | "
      f"Validate | Acc: {val_acc:.4f} | Sens: {val_sens:.4f} | Spec: {val_spec:.4f} | F1: {val_f1:.4f} || "
      f"Final Test | Acc: {final_acc:.4f} | Sens: {final_sens:.4f} | Spec: {final_spec:.4f} | F1: {final_f1:.4f} | "
      f"TP: {tp} | FP: {fp} | FN: {fn} | TN: {tn} | "
      f"Validation Loss: {validation_loss:.4f} | Test Loss: {test_loss:.4f}")


      #after all epochs of the fold finished ===
        #print(f"\nMisclassified images for Fold {fold}:")
        for fold_id, epoch_id, filename, true_label, pred_label in misclassified_final_samples:
         if epoch_id == n_epochs:  # only print misclassifications from final epoch
            print(f"[Fold {fold_id}] {filename} | True: {true_label} → Predicted: {pred_label}")

#save misclassified Final Test images for this fold ===
output_path = f"/content/drive/MyDrive/Dataset/misclassified_fold_{fold}.txt"
with open(output_path, "w") as f:
  for fold_id, epoch_id, filename, true_label, pred_label in misclassified_final_samples:
    f.write(f"Fold {fold_id}, Epoch {epoch_id}, File: {filename}, True Label: {true_label}, Predicted: {pred_label}\n")
# Out:
#  Fold 1
# Extracting DINOv2 features...
# Feature extraction successful.
# Epoch 1/50 | Train | Loss: 2.2939 | Acc: 0.5667 | Sens: 0.8889 | Spec: 0.2444 | F1: 0.6723 | Validate | Acc: 0.6522 | Sens: 0.8333 | Spec: 0.4545 | F1: 0.7143 || Final Test |
| Acc: 0.9889 | Sens: 0.9783 | Spec: 1.0000 | F1: 0.9890 | Validate | Acc: 0.9565 | Sens: 0.9091 | Spec: 1.0000 | F1: 0.9524 || Final Test | Acc: 0.6897 | Sens: 0.5000 | Spec: 0.8667 | F1: 0.6087 | TP: 7 | FP: 2 | FN: 7 | TN: 13 | Validation Loss: 0.1536 | Test Loss: 1.0406
# Epoch 40/50 | Train | Loss: 0.2147 | Acc: 0.9889 | Sens: 0.9783 | Spec: 1.0000 | F1: 0.9890 | Validate | Acc: 0.9565 | Sens: 0.9091 | Spec: 1.0000 | F1: 0.9524 || Final Test | Acc: 0.6897 | Sens: 0.5000 | Spec: 0.8667 | F1: 0.6087 | TP: 7 | FP: 2 | FN: 7 | TN: 13 | Validation Loss: 0.1561 | Test Loss: 1.0437
# Epoch 41/50 | Train | Loss: 0.2063 | Acc: 1.0000 | Sens: 1.0000 | Spec: 1.0000 | F1: 1.0000 | Validate | Acc: 0.9565 | Sens: 0.9091 | Spec: 1.0000 | F1: 0.9524 || Final Test | Acc: 0.6897 | Sens: 0.5000 | Spec: 0.8667 | F1: 0.6087 | TP: 7 | FP: 2 | FN: 7 | TN: 13 | Validation Loss: 0.1582 | Test Loss: 1.0490
# Epoch 42/50 | Train | Loss: 0.2096 | Acc: 1.0000 | Sens: 1.0000 | Spec: 1.0000 | F1: 1.0000 | Validate | Acc: 0.9565 | Sens: 0.9091 | Spec: 1.0000 | F1: 0.9524 || Final Test | Acc: 0.6897 | Sens: 0.5000 | Spec: 0.8667 | F1: 0.6087 | TP: 7 | FP: 2 | FN: 7 | TN: 13 | Validation Loss: 0.1600 | Test Loss: 1.0537
# Epoch 43/50 | Train | Loss: 0.2071 | Acc: 1.0000 | Sens: 1.0000 | Spec: 1.0000 | F1: 1.0000 | Validate | Acc: 0.9565 | Sens: 0.9091 | Spec: 1.0000 | F1: 0.9524 || Final Test | Acc: 0.6897 | Sens: 0.5000 | Spec: 0.8667 | F1: 0.6087 | TP: 7 | FP: 2 | FN: 7 | TN: 13 | Validation Loss: 0.1615 | Test Loss: 1.0597
# Epoch 44/50 | Train | Loss: 0.1980 | Acc: 1.0000 | Sens: 1.0000 | Spec: 1.0000 | F1: 1.0000 | Validate | Acc: 0.9565 | Sens: 0.9091 | Spec: 1.0000 | F1: 0.9524 || Final Test | Acc: 0.6897 | Sens: 0.5000 | Spec: 0.8667 | F1: 0.6087 | TP: 7 | FP: 2 | FN: 7 | TN: 13 | Validation Loss: 0.1639 | Test Loss: 1.0639
# Epoch 45/50 | Train | Loss: 0.2005 | Acc: 1.0000 | Sens: 1.0000 | Spec: 1.0000 | F1: 1.0000 | Validate | Acc: 0.9565 | Sens: 0.9091 | Spec: 1.0000 | F1: 0.9524 || Final Test | Acc: 0.6897 | Sens: 0.5000 | Spec: 0.8667 | F1: 0.6087 | TP: 7 | FP: 2 | FN: 7 | TN: 13 | Validation Loss: 0.1654 | Test Loss: 1.0690
# Epoch 46/50 | Train | Loss: 0.1936 | Acc: 1.0000 | Sens: 1.0000 | Spec: 1.0000 | F1: 1.0000 | Validate | Acc: 0.9565 | Sens: 0.9091 | Spec: 1.0000 | F1: 0.9524 || Final Test | Acc: 0.6897 | Sens: 0.5000 | Spec: 0.8667 | F1: 0.6087 | TP: 7 | FP: 2 | FN: 7 | TN: 13 | Validation Loss: 0.1677 | Test Loss: 1.0726
# Epoch 47/50 | Train | Loss: 0.1964 | Acc: 1.0000 | Sens: 1.0000 | Spec: 1.0000 | F1: 1.0000 | Validate | Acc: 0.9565 | Sens: 0.9091 | Spec: 1.0000 | F1: 0.9524 || Final Test | Acc: 0.6897 | Sens: 0.5000 | Spec: 0.8667 | F1: 0.6087 | TP: 7 | FP: 2 | FN: 7 | TN: 13 | Validation Loss: 0.1697 | Test Loss: 1.0774
# Epoch 48/50 | Train | Loss: 0.1907 | Acc: 1.0000 | Sens: 1.0000 | Spec: 1.0000 | F1: 1.0000 | Validate | Acc: 0.9565 | Sens: 0.9091 | Spec: 1.0000 | F1: 0.9524 || Final Test | Acc: 0.6897 | Sens: 0.5000 | Spec: 0.8667 | F1: 0.6087 | TP: 7 | FP: 2 | FN: 7 | TN: 13 | Validation Loss: 0.1715 | Test Loss: 1.0810
# Epoch 49/50 | Train | Loss: 0.1838 | Acc: 1.0000 | Sens: 1.0000 | Spec: 1.0000 | F1: 1.0000 | Validate | Acc: 0.9565 | Sens: 0.9091 | Spec: 1.0000 | F1: 0.9524 || Final Test | Acc: 0.6897 | Sens: 0.5000 | Spec: 0.8667 | F1: 0.6087 | TP: 7 | FP: 2 | FN: 7 | TN: 13 | Validation Loss: 0.1737 | Test Loss: 1.0851
# Epoch 50/50 | Train | Loss: 0.1801 | Acc: 1.0000 | Sens: 1.0000 | Spec: 1.0000 | F1: 1.0000 | Validate | Acc: 0.9565 | Sens: 0.9091 | Spec: 1.0000 | F1: 0.9524 || Final Test | Acc: 0.6897 | Sens: 0.5000 | Spec: 0.8667 | F1: 0.6087 | TP: 7 | FP: 2 | FN: 7 | TN: 13 | Validation Loss: 0.1764 | Test Loss: 1.0874
#
#  Fold 4
# Extracting DINOv2 features...
# Feature extraction successful.
# Epoch 1/50 | Train | Loss: 0.2755 | Acc: 0.9670 | Sens: 0.9348 | Spec: 1.0000 | F1: 0.9663 | Validate | Acc: 0.9545 | Sens: 0.9091 | Spec: 1.0000 | F1: 0.9524 || Final Test | Acc: 0.7241 | Sens: 0.4286 | Spec: 1.0000 | F1: 0.6000 | TP: 6 | FP: 0 | FN: 8 | TN: 15 | Validation Loss: 0.0570 | Test Loss: 1.1455
# Epoch 2/50 | Train | Loss: 0.2483 | Acc: 0.9780 | Sens: 0.9565 | Spec: 1.0000 | F1: 0.9778 | Validate | Acc: 0.9545 | Sens: 0.9091 | Spec: 1.0000 | F1: 0.9524 || Final Test | Acc: 0.6552 | Sens: 0.4286 | Spec: 0.8667 | F1: 0.5455 | TP: 6 | FP: 2 | FN: 8 | TN: 13 | Validation Loss: 0.0632 | Test Loss: 1.1552
# Epoch 3/50 | Train | Loss: 0.2328 | Acc: 1.0000 | Sens: 1.0000 | Spec: 1.0000 | F1: 1.0000 | Validate | Acc: 0.9545 | Sens: 0.9091 | Spec: 1.0000 | F1: 0.9524 || Final Test | Acc: 0.6897 | Sens: 0.5000 | Spec: 0.8667 | F1: 0.6087 | TP: 7 | FP: 2 | FN: 7 | TN: 13 | Validation Loss: 0.0700 | Test Loss: 1.1648
# ...
# Epoch 50/50 | Train | Loss: 0.0792 | Acc: 1.0000 | Sens: 1.0000 | Spec: 1.0000 | F1: 1.0000 | Validate | Acc: 0.9091 | Sens: 0.9091 | Spec: 0.9091 | F1: 0.9091 || Final Test | Acc: 0.6897 | Sens: 0.7143 | Spec: 0.6667 | F1: 0.6897 | TP: 10 | FP: 5 | FN: 4 | TN: 10 | Validation Loss: 0.2431 | Test Loss: 1.3605
#
#  Fold 5
# Extracting DINOv2 features...
# Feature extraction successful.
# Epoch 1/50 | Train | Loss: 0.2445 | Acc: 0.9231 | Sens: 0.8478 | Spec: 1.0000 | F1: 0.9176 | Validate | Acc: 0.9545 | Sens: 0.9091 | Spec: 1.0000 | F1: 0.9524 || Final Test | Acc: 0.6897 | Sens: 0.3571 | Spec: 1.0000 | F1: 0.5263 | TP: 5 | FP: 0 | FN: 9 | TN: 15 | Validation Loss: 0.0222 | Test Loss: 1.3391
# Epoch 2/50 | Train | Loss: 0.2346 | Acc: 0.9121 | Sens: 0.8261 | Spec: 1.0000 | F1: 0.9048 | Validate | Acc: 0.9545 | Sens: 0.9091 | Spec: 1.0000 | F1: 0.9524 || Final Test | Acc: 0.6897 | Sens: 0.3571 | Spec: 1.0000 | F1: 0.5263 | TP: 5 | FP: 0 | FN: 9 | TN: 15 | Validation Loss: 0.0221 | Test Loss: 1.3278
# Epoch 3/50 | Train | Loss: 0.2037 | Acc: 0.9011 | Sens: 0.8043 | Spec: 1.0000 | F1: 0.8916 | Validate | Acc: 0.9545 | Sens: 0.9091 | Spec: 1.0000 | F1: 0.9524 || Final Test | Acc: 0.6897 | Sens: 0.3571 | Spec: 1.0000 | F1: 0.5263 | TP: 5 | FP: 0 | FN: 9 | TN: 15 | Validation Loss: 0.0222 | Test Loss: 1.3140
# Epoch 4/50 | Train | Loss: 0.1849 | Acc: 0.9121 | Sens: 0.8261 | Spec: 1.0000 | F1: 0.9048 | Validate | Acc: 0.9545 | Sens: 0.9091 | Spec: 1.0000 | F1: 0.9524 || Final Test | Acc: 0.6897 | Sens: 0.3571 | Spec: 1.0000 | F1: 0.5263 | TP: 5 | FP: 0 | FN: 9 | TN: 15 | Validation Loss: 0.0228 | Test Loss: 1.3074
# Epoch 5/50 | Train | Loss: 0.1685 | Acc: 0.9121 | Sens: 0.8261 | Spec: 1.0000 | F1: 0.9048 | Validate | Acc: 0.9545 | Sens: 0.9091 | Spec: 1.0000 | F1: 0.9524 || Final Test | Acc: 0.6897 | Sens: 0.3571 | Spec: 1.0000 | F1: 0.5263 | TP: 5 | FP: 0 | FN: 9 | TN: 15 | Validation Loss: 0.0233 | Test Loss: 1.3012
# Epoch 6/50 | Train | Loss: 0.1571 | Acc: 0.9121 | Sens: 0.8261 | Spec: 1.0000 | F1: 0.9048 | Validate | Acc: 0.9545 | Sens: 0.9091 | Spec: 1.0000 | F1: 0.9524 || Final Test | Acc: 0.6897 | Sens: 0.3571 | Spec: 1.0000 | F1: 0.5263 | TP: 5 | FP: 0 | FN: 9 | TN: 15 | Validation Loss: 0.0239 | Test Loss: 1.3010
# Epoch 7/50 | Train | Loss: 0.1427 | Acc: 0.9121 | Sens: 0.8261 | Spec: 1.0000 | F1: 0.9048 | Validate | Acc: 0.9545 | Sens: 0.9091 | Spec: 1.0000 | F1: 0.9524 || Final Test | Acc: 0.6897 | Sens: 0.3571 | Spec: 1.0000 | F1: 0.5263 | TP: 5 | FP: 0 | FN: 9 | TN: 15 | Validation Loss: 0.0244 | Test Loss: 1.3019
# Epoch 8/50 | Train | Loss: 0.1344 | Acc: 0.9121 | Sens: 0.8261 | Spec: 1.0000 | F1: 0.9048 | Validate | Acc: 0.9545 | Sens: 0.9091 | Spec: 1.0000 | F1: 0.9524 || Final Test | Acc: 0.6897 | Sens: 0.3571 | Spec: 1.0000 | F1: 0.5263 | TP: 5 | FP: 0 | FN: 9 | TN: 15 | Validation Loss: 0.0249 | Test Loss: 1.3071
# Epoch 9/50 | Train | Loss: 0.1291 | Acc: 0.9121 | Sens: 0.8261 | Spec: 1.0000 | F1: 0.9048 | Validate | Acc: 0.9545 | Sens: 0.9091 | Spec: 1.0000 | F1: 0.9524 || Final Test | Acc: 0.6897 | Sens: 0.3571 | Spec: 1.0000 | F1: 0.5263 | TP: 5 | FP: 0 | FN: 9 | TN: 15 | Validation Loss: 0.0252 | Test Loss: 1.3135
# Epoch 10/50 | Train | Loss: 0.1266 | Acc: 0.9011 | Sens: 0.8043 | Spec: 1.0000 | F1: 0.8916 | Validate | Acc: 0.9545 | Sens: 0.9091 | Spec: 1.0000 | F1: 0.9524 || Final Test | Acc: 0.6897 | Sens: 0.3571 | Spec: 1.0000 | F1: 0.5263 | TP: 5 | FP: 0 | FN: 9 | TN: 15 | Validation Loss: 0.
| Sens: 0.9565 | Spec: 1.0000 | F1: 0.9778 | Validate | Acc: 0.9545 | Sens: 0.9091 | Spec: 1.0000 | F1: 0.9524 || Final Test | Acc: 0.6897 | Sens: 0.3571 | Spec: 1.0000 | F1: 0.5263 | TP: 5 | FP: 0 | FN: 9 | TN: 15 | Validation Loss: 0.0326 | Test Loss: 1.4256
# Epoch 39/50 | Train | Loss: 0.0770 | Acc: 0.9780 | Sens: 0.9565 | Spec: 1.0000 | F1: 0.9778 | Validate | Acc: 0.9545 | Sens: 0.9091 | Spec: 1.0000 | F1: 0.9524 || Final Test | Acc: 0.6897 | Sens: 0.3571 | Spec: 1.0000 | F1: 0.5263 | TP: 5 | FP: 0 | FN: 9 | TN: 15 | Validation Loss: 0.0329 | Test Loss: 1.4271
# Epoch 40/50 | Train | Loss: 0.0757 | Acc: 0.9780 | Sens: 0.9565 | Spec: 1.0000 | F1: 0.9778 | Validate | Acc: 0.9545 | Sens: 0.9091 | Spec: 1.0000 | F1: 0.9524 || Final Test | Acc: 0.6897 | Sens: 0.3571 | Spec: 1.0000 | F1: 0.5263 | TP: 5 | FP: 0 | FN: 9 | TN: 15 | Validation Loss: 0.0331 | Test Loss: 1.4300
# Epoch 41/50 | Train | Loss: 0.0730 | Acc: 0.9780 | Sens: 0.9565 | Spec: 1.0000 | F1: 0.9778 | Validate | Acc: 0.9545 | Sens: 0.9091 | Spec: 1.0000 | F1: 0.9524 || Final Test | Acc: 0.6897 | Sens: 0.3571 | Spec: 1.0000 | F1: 0.5263 | TP: 5 | FP: 0 | FN: 9 | TN: 15 | Validation Loss: 0.0334 | Test Loss: 1.4340
# Epoch 42/50 | Train | Loss: 0.0728 | Acc: 0.9890 | Sens: 0.9783 | Spec: 1.0000 | F1: 0.9890 | Validate | Acc: 0.9545 | Sens: 0.9091 | Spec: 1.0000 | F1: 0.9524 || Final Test | Acc: 0.6897 | Sens: 0.3571 | Spec: 1.0000 | F1: 0.5263 | TP: 5 | FP: 0 | FN: 9 | TN: 15 | Validation Loss: 0.0337 | Test Loss: 1.4368
# Epoch 43/50 | Train | Loss: 0.0716 | Acc: 0.9890 | Sens: 0.9783 | Spec: 1.0000 | F1: 0.9890 | Validate | Acc: 0.9545 | Sens: 0.9091 | Spec: 1.0000 | F1: 0.9524 || Final Test | Acc: 0.6897 | Sens: 0.3571 | Spec: 1.0000 | F1: 0.5263 | TP: 5 | FP: 0 | FN: 9 | TN: 15 | Validation Loss: 0.0340 | Test Loss: 1.4394
# Epoch 44/50 | Train | Loss: 0.0708 | Acc: 0.9890 | Sens: 0.9783 | Spec: 1.0000 | F1: 0.9890 | Validate | Acc: 0.9545 | Sens: 0.9091 | Spec: 1.0000 | F1: 0.9524 || Final Test | Acc: 0.6897 | Sens: 0.3571 | Spec: 1.0000 | F1: 0.5263 | TP: 5 | FP: 0 | FN: 9 | TN: 15 | Validation Loss: 0.0344 | Test Loss: 1.4417
# Epoch 45/50 | Train | Loss: 0.0690 | Acc: 0.9890 | Sens: 0.9783 | Spec: 1.0000 | F1: 0.9890 | Validate | Acc: 0.9545 | Sens: 0.9091 | Spec: 1.0000 | F1: 0.9524 || Final Test | Acc: 0.6897 | Sens: 0.3571 | Spec: 1.0000 | F1: 0.5263 | TP: 5 | FP: 0 | FN: 9 | TN: 15 | Validation Loss: 0.0347 | Test Loss: 1.4442
# Epoch 46/50 | Train | Loss: 0.0684 | Acc: 1.0000 | Sens: 1.0000 | Spec: 1.0000 | F1: 1.0000 | Validate | Acc: 0.9545 | Sens: 0.9091 | Spec: 1.0000 | F1: 0.9524 || Final Test | Acc: 0.6897 | Sens: 0.3571 | Spec: 1.0000 | F1: 0.5263 | TP: 5 | FP: 0 | FN: 9 | TN: 15 | Validation Loss: 0.0351 | Test Loss: 1.4466
# Epoch 47/50 | Train | Loss: 0.0674 | Acc: 1.0000 | Sens: 1.0000 | Spec: 1.0000 | F1: 1.0000 | Validate | Acc: 0.9545 | Sens: 0.9091 | Spec: 1.0000 | F1: 0.9524 || Final Test | Acc: 0.6897 | Sens: 0.3571 | Spec: 1.0000 | F1: 0.5263 | TP: 5 | FP: 0 | FN: 9 | TN: 15 | Validation Loss: 0.0354 | Test Loss: 1.4485
# Epoch 48/50 | Train | Loss: 0.0663 | Acc: 1.0000 | Sens: 1.0000 | Spec: 1.0000 | F1: 1.0000 | Validate | Acc: 0.9545 | Sens: 0.9091 | Spec: 1.0000 | F1: 0.9524 || Final Test | Acc: 0.6897 | Sens: 0.3571 | Spec: 1.0000 | F1: 0.5263 | TP: 5 | FP: 0 | FN: 9 | TN: 15 | Validation Loss: 0.0357 | Test Loss: 1.4509
# Epoch 49/50 | Train | Loss: 0.0671 | Acc: 1.0000 | Sens: 1.0000 | Spec: 1.0000 | F1: 1.0000 | Validate | Acc: 0.9545 | Sens: 0.9091 | Spec: 1.0000 | F1: 0.9524 || Final Test | Acc: 0.6897 | Sens: 0.3571 | Spec: 1.0000 | F1: 0.5263 | TP: 5 | FP: 0 | FN: 9 | TN: 15 | Validation Loss: 0.0361 | Test Loss: 1.4529
# Epoch 50/50 | Train | Loss: 0.0662 | Acc: 1.0000 | Sens: 1.0000 | Spec: 1.0000 | F1: 1.0000 | Validate | Acc: 0.9545 | Sens: 0.9091 | Spec: 1.0000 | F1: 0.9524 || Final Test | Acc: 0.6897 | Sens: 0.3571 | Spec: 1.0000 | F1: 0.5263 | TP: 5 | FP: 0 | FN: 9 | TN: 15 | Validation Loss: 0.0364 | Test Loss: 1.4558

# %%
# Classification using MLP head (no block unfreezing + sensitivity-prioritized threshold)
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, f1_score
import os
import glob

# Custom dataset class with optional augmentation
class AugmentedTensorDataset(Dataset):
    def __init__(self, X, y, transform=None):
        self.X = X
        self.y = y
        self.transform = transform

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        x = self.X[idx]
        y = self.y[idx]
        if self.transform:
            x = self.transform(x)
        return x, y

# Ensure model is loaded
assert 'model' in globals(), "DINOv2 model not loaded!"

# Set the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Freeze all ViT parameters (no unfreezing)
for param in model.parameters():
    param.requires_grad = False

# Define MLP head (trainable by default)
num_features = model.norm.weight.shape[0]
model.fc = nn.Sequential(
    nn.Linear(num_features, 128),
    nn.BatchNorm1d(128),
    nn.ReLU(),
    nn.Dropout(0.5),
    nn.Linear(128, 1)
).to(device)

folds_folder = "/content/drive/MyDrive/Dataset/Split_FoldsBalanced"
label_mapping = {"Healthy": 0, "Unhealthy": 1}
n_epochs = 50
batch_size = 32
learning_rate = 2e-4
weight_decay = 1e-4

# Loop through each fold
for fold in range(1, 6):
    print(f"\nTraining on Fold {fold}...")
    final_test_folder = os.path.join("/content/drive/MyDrive/Dataset/Split_Folds/SPLITSBalanced", f"fold_{fold}", "Final Test")
    final_filenames = sorted([os.path.basename(f) for f in glob.glob(os.path.join(final_test_folder, "*"))])

    fold_path = os.path.join(folds_folder, f"dinov2_fold_{fold}.pt")
    data = torch.load(fold_path, map_location=device, weights_only=False)

    X_train = data["X_train"].float().to(device)
    y_train = torch.tensor([label_mapping[l] for l in data["y_train"]], dtype=torch.float32, device=device)
    X_test = data["X_test"].float().to(device)
    y_test = torch.tensor([label_mapping[l] for l in data["y_test"]], dtype=torch.float32, device=device)
    X_final = data["X_final"].float().to(device)
    y_final = torch.tensor([label_mapping[l] for l in data["y_final"]], dtype=torch.float32, device=device)

    pos_weight = torch.tensor([len(y_train) / (2 * y_train.sum())], dtype=torch.float32, device=device)
    criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight)
    optimizer = optim.AdamW(model.fc.parameters(), lr=learning_rate, weight_decay=weight_decay)

    mean = X_train.mean(dim=(0, 2, 3), keepdim=True)
    std = X_train.std(dim=(0, 2, 3), keepdim=True) + 1e-6

    train_transform = transforms.Compose([
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(45),
        transforms.ColorJitter(brightness=0.6, contrast=0.6),
        transforms.RandomErasing(p=0.7, scale=(0.02, 0.25)),
        transforms.Normalize(mean=mean.squeeze(), std=std.squeeze()),
    ])
    test_transform = transforms.Compose([
        transforms.Normalize(mean=mean.squeeze(), std=std.squeeze())
    ])

    train_dataset = AugmentedTensorDataset(X_train, y_train, train_transform)
    test_dataset = AugmentedTensorDataset(X_test, y_test, test_transform)
    final_dataset = AugmentedTensorDataset(X_final, y_final, test_transform)

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=batch_size)
    final_loader = DataLoader(final_dataset, batch_size=batch_size)

    misclassified_final_samples = []

    for epoch in range(n_epochs):
        model.train()
        train_loss = 0
        train_preds_raw, train_labels = [], []

        for batch_X, batch_y in train_loader:
            optimizer.zero_grad()
            outputs = model.fc(model.forward_features(batch_X)["x_norm_clstoken"]).squeeze(1)
            loss = criterion(outputs, batch_y)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()
            train_preds_raw.extend(outputs.detach().cpu().numpy())
            train_labels.extend(batch_y.cpu().numpy())

        model.eval()
        val_preds_raw, val_labels = [], []
        val_loss = 0
        with torch.no_grad():
            for batch_X, batch_y in test_loader:
                outputs = model.fc(model.forward_features(batch_X)["x_norm_clstoken"]).squeeze(1)
                loss = criterion(outputs, batch_y)
                val_loss += loss.item()
                val_preds_raw.extend(outputs.cpu().numpy())
                val_labels.extend(batch_y.cpu().numpy())

        # Threshold selection: Sens ≥ 0.90, then max F1
        fpr, tpr, thresholds = roc_curve(val_labels, val_preds_raw)
        high_sens_mask = tpr >= 0.90
        candidate_thresholds = thresholds[high_sens_mask]

        if candidate_thresholds.size > 0:
            f1_scores = []
            for i, thresh in enumerate(candidate_thresholds):
                preds = (np.array(val_preds_raw) > thresh).astype(int)
                if (tpr[high_sens_mask][i] >= 0.90):
                    f1_scores.append(f1_score(val_labels, preds))
                else:
                    f1_scores.append(0)
            best_threshold = candidate_thresholds[np.argmax(f1_scores)]
        else:
            print("No threshold satisfies sensitivity ≥ 0.90 — using 0.5 fallback.")
            best_threshold = 0.5

        # Train metrics
        train_preds = (np.array(train_preds_raw) > best_threshold).astype(int)
        train_acc = accuracy_score(train_labels, train_preds)
        tn, fp, fn, tp = confusion_matrix(train_labels, train_preds).ravel()
        train_sens = tp / (tp + fn) if (tp + fn) > 0 else 0
        train_spec = tn / (tn + fp) if (tn + fp) > 0 else 0
        train_f1 = f1_score(train_labels, train_preds)

        # Validation metrics
        val_preds = (np.array(val_preds_raw) > best_threshold).astype(int)
        val_f1 = f1_score(val_labels, val_preds)
        val_acc = accuracy_score(val_labels, val_preds)
        tn, fp, fn, tp = confusion_matrix(val_labels, val_preds).ravel()
        val_sens = tp / (tp + fn) if (tp + fn) > 0 else 0
        val_spec = tn / (tn + fp) if (tn + fp) > 0 else 0

        # Final test metrics
        final_preds_raw, final_labels = [], []
        final_loss = 0
        with torch.no_grad():
            for batch_X, batch_y in final_loader:
                outputs = model.fc(model.forward_features(batch_X)["x_norm_clstoken"]).squeeze(1)
                loss = criterion(outputs, batch_y)
                final_loss += loss.item()
                final_preds_raw.extend(outputs.cpu().numpy())
                final_labels.extend(batch_y.cpu().numpy())

        final_preds = (np.array(final_preds_raw) > best_threshold).astype(int)
        final_f1 = f1_score(final_labels, final_preds)
        final_acc = accuracy_score(final_labels, final_preds)
        tn_f, fp_f, fn_f, tp_f = confusion_matrix(final_labels, final_preds).ravel()
        final_sens = tp_f / (tp_f + fn_f) if (tp_f + fn_f) > 0 else 0
        final_spec = tn_f / (tn_f + fp_f) if (tn_f + fp_f) > 0 else 0

        print(f"Epoch {epoch+1}/{n_epochs} |  Train | Loss: {train_loss:.4f} | Acc: {train_acc:.4f} | Sens: {train_sens:.4f} | Spec: {train_spec:.4f} | F1: {train_f1:.4f} | "
        f"Validate | Loss : {val_loss:.4f} | Acc: {val_acc:.4f} | Sens: {val_sens:.4f} | Spec: {val_spec:.4f} | F1: {val_f1:.4f} || "
        f"Final Test | Loss : {final_loss:.4f} | Acc: {final_acc:.4f} | Sens: {final_sens:.4f} | Spec: {final_spec:.4f} | F1: {final_f1:.4f} | "
       f"TP: {tp_f} | FP: {fp_f} | FN: {fn_f} | TN: {tn_f}")

        if epoch == n_epochs - 1:
            for global_idx, (pred, label) in enumerate(zip(final_preds, final_labels)):
                if pred != label:
                    filename = final_filenames[global_idx]
                    misclassified_final_samples.append((fold, epoch+1, filename, int(label), int(pred)))

    print(f"\nMisclassified images for Fold {fold}:")
    for fold_id, epoch_id, filename, true_label, pred_label in misclassified_final_samples:
        print(f"[Fold {fold_id}] {filename} | True: {true_label} → Predicted: {pred_label}")

# %%
#Classification using MLP head using Youden's Index and unfreezing block 11
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, f1_score
import os
import glob

#custom dataset class with optional augmentation
class AugmentedTensorDataset(Dataset):
    def __init__(self, X, y, transform=None):
        self.X = X #input features
        self.y = y #labels 1 or 0
        self.transform = transform #optional data augm

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        x = self.X[idx]
        y = self.y[idx]
        if self.transform:
            x = self.transform(x)
        return x, y

#ensure model is loaded
assert 'model' in globals(), "DINOv2 model not loaded!"
#set the device for training
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Define final_filenames for tracking misclassified images
final_test_folder = os.path.join("/content/drive/MyDrive/Dataset/Split_FoldsBalanced/SPLITS", f"fold_{fold}", "Final Test")
final_filenames = sorted([os.path.basename(f) for f in glob.glob(os.path.join(final_test_folder, "*"))])

#freeze all model parameters except for final transformer block and classfication head
for param in model.parameters():
    param.requires_grad = False
for name, param in model.named_parameters():
    if "block.11" in name or "fc" in name:
        param.requires_grad = True

#MLP HEAD
num_features = model.norm.weight.shape[0]
model.fc = nn.Sequential(
    nn.Linear(num_features, 128),
    nn.BatchNorm1d(128),
    nn.ReLU(),
    nn.Dropout(0.5),
    nn.Linear(128, 1)
).to(device)


folds_folder = "/content/drive/MyDrive/Dataset/Split_FoldsBalanced"
label_mapping = {"Healthy": 0, "Unhealthy": 1} #map classes
n_epochs = 50
batch_size = 32
learning_rate_fc = 2e-4
learning_rate_vit = 5e-7
weight_decay = 1e-4

#loop over each fold
for fold in range(1, 6):
    print(f"\nTraining on Fold {fold}...")
 #load fold data
    fold_path = os.path.join(folds_folder, f"dinov2_fold_{fold}.pt")
    data = torch.load(fold_path, map_location=device, weights_only=False)
#extract features and labels and move to device
    X_train = data["X_train"].float().to(device)
    y_train = torch.tensor([label_mapping[l] for l in data["y_train"]], dtype=torch.float32, device=device)
    X_test = data["X_test"].float().to(device)
    y_test = torch.tensor([label_mapping[l] for l in data["y_test"]], dtype=torch.float32, device=device)
    X_final = data["X_final"].float().to(device)
    y_final = torch.tensor([label_mapping[l] for l in data["y_final"]], dtype=torch.float32, device=device)
    #handle class imbalance by using a positive class weight
    pos_weight = torch.tensor([len(y_train) / (2 * y_train.sum())], dtype=torch.float32, device=device)
    criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight)

    #optimizer for mlp and last block
    optimizer = optim.AdamW([
        {'params': model.fc.parameters(), 'lr': learning_rate_fc},
        {'params': model.blocks[11:].parameters(), 'lr': learning_rate_vit},
    ], weight_decay=weight_decay)

    #learning rate scheduler
    scheduler = optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=10, T_mult=2)

    #compute mean and std for normalization
    mean = X_train.mean(dim=(0, 2, 3), keepdim=True)
    std = X_train.std(dim=(0, 2, 3), keepdim=True) + 1e-6

    #define data augmentation
    train_transform = transforms.Compose([
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(45),
        transforms.ColorJitter(brightness=0.6, contrast=0.6),
        transforms.RandomErasing(p=0.7, scale=(0.02, 0.25)),
        transforms.Normalize(mean=mean.squeeze(), std=std.squeeze()),
    ])
    test_transform = transforms.Compose([transforms.Normalize(mean=mean.squeeze(), std=std.squeeze())])

    #create datasets and data loaders
    train_dataset = AugmentedTensorDataset(X_train, y_train, train_transform)
    test_dataset = AugmentedTensorDataset(X_test, y_test, test_transform)
    final_dataset = AugmentedTensorDataset(X_final, y_final, test_transform)

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
    final_loader = DataLoader(final_dataset, batch_size=batch_size, shuffle=False)
    #create a list to track misclassified samples
    misclassified_final_samples = []

    #training loop
    for epoch in range(n_epochs):
        model.train()
        train_loss = 0
        train_preds_raw, train_labels = [], []

        #TRAINING
        for batch_X, batch_y in train_loader:
            optimizer.zero_grad()
            #forward pass through vit and mlp
            outputs = model.fc(model.forward_features(batch_X)["x_norm_clstoken"]).squeeze(1)
            loss = criterion(outputs, batch_y)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()
            train_preds_raw.extend(outputs.detach().cpu().numpy())
            train_labels.extend(batch_y.cpu().numpy())

        #optimal threshold using roc curve
        fpr, tpr, thresholds = roc_curve(train_labels, train_preds_raw)
        best_threshold = thresholds[np.argmax(tpr - fpr)]
        train_preds = (np.array(train_preds_raw) > best_threshold).astype(int)
        train_f1 = f1_score(train_labels, train_preds)
        train_acc = accuracy_score(train_labels, train_preds)
        tn, fp, fn, tp = confusion_matrix(train_labels, train_preds).ravel()
        train_sens = tp / (tp + fn) if (tp + fn) > 0 else 0
        train_spec = tn / (tn + fp) if (tn + fp) > 0 else 0

        #VALIDATION
        model.eval()
        val_preds_raw, val_labels = [], []
        val_loss = 0
        with torch.no_grad():
            for batch_X, batch_y in test_loader:
                outputs = model.fc(model.forward_features(batch_X)["x_norm_clstoken"]).squeeze(1)
                loss = criterion(outputs, batch_y)
                val_loss += loss.item()
                val_preds_raw.extend(outputs.cpu().numpy())
                val_labels.extend(batch_y.cpu().numpy())

        val_preds = (np.array(val_preds_raw) > best_threshold).astype(int)
        val_f1 = f1_score(val_labels, val_preds)
        val_acc = accuracy_score(val_labels, val_preds)
        tn, fp, fn, tp = confusion_matrix(val_labels, val_preds).ravel()
        val_sens = tp / (tp + fn) if (tp + fn) > 0 else 0
        val_spec = tn / (tn + fp) if (tn + fp) > 0 else 0

        #FINAL TESTING
        final_preds_raw, final_labels = [], []
        final_loss = 0
        with torch.no_grad():
            for batch_X, batch_y in final_loader:
                outputs = model.fc(model.forward_features(batch_X)["x_norm_clstoken"]).squeeze(1)
                loss = criterion(outputs, batch_y)
                final_loss += loss.item()
                final_preds_raw.extend(outputs.cpu().numpy())
                final_labels.extend(batch_y.cpu().numpy())

        final_preds = (np.array(final_preds_raw) > best_threshold).astype(int)
        final_f1 = f1_score(final_labels, final_preds)
        final_acc = accuracy_score(final_labels, final_preds)
        tn_f, fp_f, fn_f, tp_f = confusion_matrix(final_labels, final_preds).ravel()
        final_sens = tp_f / (tp_f + fn_f) if (tp_f + fn_f) > 0 else 0
        final_spec = tn_f / (tn_f + fp_f) if (tn_f + fp_f) > 0 else 0


        print(f"Epoch {epoch+1}/{n_epochs} |  Train | Loss: {train_loss:.4f} | Acc: {train_acc:.4f} | Sens: {train_sens:.4f} | Spec: {train_spec:.4f} | F1: {train_f1:.4f} | "
      f"Validate | Loss : {val_loss:.4f} | Acc: {val_acc:.4f} | Sens: {val_sens:.4f} | Spec: {val_spec:.4f} | F1: {val_f1:.4f} || "
      f"Final Test | Loss : {final_loss:.4f} | Acc: {final_acc:.4f} | Sens: {final_sens:.4f} | Spec: {final_spec:.4f} | F1: {final_f1:.4f} | "
      f"TP: {tp_f} | FP: {fp_f} | FN: {fn_f} | TN: {tn_f}")


  #       #track misclassified images in final test
  #   if epoch == n_epochs - 1:  # only track misclassified images after the final epoch
  #       for global_idx, (pred, label) in enumerate(zip(final_preds, final_labels)):
  #           if pred != label:
  #               filename = final_filenames[global_idx]
  #               misclassified_final_samples.append((fold, epoch+1, filename, int(label), int(pred)))
  #       scheduler.step()
  #  #after all epochs for this fold, print and save the misclassified images
  #   print(f"\nMisclassified images for Fold {fold}:")
  #   for fold_id, epoch_id, filename, true_label, pred_label in misclassified_final_samples:
  #      if epoch_id == n_epochs:  # Only print misclassifications from final epoch
  #       print(f"[Fold {fold_id}] {filename} | True: {true_label} → Predicted: {pred_label}")
# Out:
# Training on Fold 1...
# Epoch 1/50 |  Train | Loss: 2.2133 | Acc: 0.5556 | Sens: 0.3556 | Spec: 0.7556 | F1: 0.4444 | Validate | Loss : 0.7279 | Acc: 0.4783 | Sens: 0.0000 | Spec: 1.0000 | F1: 0.0000 || Final Test | Loss : 0.6926 | Acc: 0.5172 | Sens: 0.0000 | Spec: 1.0000 | F1: 0.0000 | TP: 0 | FP: 0 | FN: 14 | TN: 15
# Epoch 9/50 |  Train | Loss: 1.9232 | Acc: 0.6667 | Sens: 0.5556 | Spec: 0.7778 | F1: 0.6250 | Validate | Loss : 0.6024 | Acc: 0.5652 | Sens: 0.8333 | Spec: 0.2727 | F1: 0.6667 || Final Test | Loss : 0.6343 | Acc: 0.6552 | Sens: 0.9286 | Spec: 0.4000 | F1: 0.7222 | TP: 13 | FP: 9 | FN: 1 | TN: 6
# Epoch 10/50 |  Train | Loss: 1.7830 | Acc: 0.6889 | Sens: 0.4222 | Spec: 0.9556 | F1: 0.5758 | Validate | Loss : 0.5943 | Acc: 0.6087 | Sens: 0.5833 | Spec: 0.6364 | F1: 0.6087 || Final Test | Loss : 0.6292 | Acc: 0.6897 | Sens: 0.7857 | Spec: 0.6000 | F1: 0.7097 | TP: 11 | FP: 6 | FN: 3 | TN: 9
# Epoch 11/50 |  Train | Loss: 1.8848 | Acc: 0.6778 | Sens: 0.4667 | Spec: 0.8889 | F1: 0.5915 | Validate | Loss : 0.5883 | Acc: 0.6522 | Sens: 0.6667 | Spec: 0.6364 | F1: 0.6667 || Final Test | Loss : 0.6237 | Acc: 0.6897 | Sens: 0.7857 | Spec: 0.6000 | F1: 0.7097 | TP: 11 | FP: 6 | FN: 3 | TN: 9
# Epoch 12/50 |  Train | Loss: 1.7590 | Acc: 0.7111 | Sens: 0.5111 | Spec: 0.9111 | F1: 0.6389 | Validate | Loss : 0.5878 | Acc: 0.6957 | Sens: 0.7500 | Spec: 0.6364 | F1: 0.7200 || Final Test | Loss : 0.6231 | Acc: 0.6897 | Sens: 0.7857 | Spec: 0.6000 | F1: 0.7097 | TP: 11 | FP: 6 | FN: 3 | TN: 9
# Epoch 13/50 |  Train | Loss: 1.6131 | Acc: 0.7667 | Sens: 0.6000 | Spec: 0.9333 | F1: 0.7200 | Validate | Loss : 0.5868 | Acc: 0.6957 | Sens: 0.7500 | Spec: 0.6364 | F1: 0.7200 || Final Test | Loss : 0.6206 | Acc: 0.6897 | Sens: 0.7857 | Spec: 0.6000 | F1: 0.7097 | TP: 11 | FP: 6 | FN: 3 | TN: 9
# Epoch 14/50 |  Train | Loss: 1.6242 | Acc: 0.7889 | Sens: 0.7333 | Spec: 0.8444 | F1: 0.7765 | Validate | Loss : 0.5909 | Acc: 0.5652 | Sens: 0.8333 | Spec: 0.2727 | F1: 0.6667 || Final Test | Loss : 0.6244 | Acc: 0.6207 | Sens: 0.9286 | Spec: 0.3333 | F1: 0.7027 | TP: 13 | FP: 10 | FN: 1 | TN: 5
# Epoch 15/50 |  Train | Loss: 1.9493 | Acc: 0.6444 | Sens: 0.3556 | Spec: 0.9333 | F1: 0.5000 | Validate | Loss : 0.5925 | Acc: 0.6957 | Sens: 0.7500 | Spec: 0.6364 | F1: 0.7200 || Final Test | Loss : 0.6265 | Acc: 0.7241 | Sens: 0.8571 | Spec: 0.6000 | F1: 0.7500 | TP: 12 | FP: 6 | FN: 2 | TN: 9
# Epoch 16/50 |  Train | Loss: 1.7118 | Acc: 0.6889 | Sens: 0.4444 | Spec: 0.9333 | F1: 0.5882 | Validate | Loss : 0.5917 | Acc: 0.6957 | Sens: 0.7500 | Spec: 0.6364 | F1: 0.7200 || Final Test | Loss : 0.6224 | Acc: 0.7241 | Sens: 0.8571 | Spec: 0.6000 | F1: 0.7500 | TP: 12 | FP: 6 | FN: 2 | TN: 9
# Epoch 17/50 |  Train | Loss: 1.6286 | Acc: 0.7333 | Sens: 0.8667 | Spec: 0.6000 | F1: 0.7647 | Validate | Loss : 0.5944 | Acc: 0.5652 | Sens: 1.0000 | Spec: 0.0909 | F1: 0.7059 || Final Test | Loss : 0.6208 | Acc: 0.5517 | Sens: 0.9286 | Spec: 0.2000 | F1: 0.6667 | TP: 13 | FP: 12 | FN: 1 | TN: 3
# Epoch 18/50 |  Train | Loss: 1.5953 | Acc: 0.7333 | Sens: 0.5333 | Spec: 0.9333 | F1: 0.6667 | Validate | Loss : 0.5905 | Acc: 0.6957 | Sens: 0.7500 | Spec: 0.6364 | F1: 0.7200 || Final Test | Loss : 0.6164 | Acc: 0.7586 | Sens: 0.9286 | Spec: 0.6000 | F1: 0.7879 | TP: 13 | FP: 6 | FN: 1 | TN: 9
# Epoch 19/50 |  Train | Loss: 1.6408 | Acc: 0.7333 | Sens: 0.6889 | Spec: 0.7778 | F1: 0.7209 | Validate | Loss : 0.5968 | Acc: 0.5652 | Sens: 0.9167 | Spec: 0.1818 | F1: 0.6875 || Final Test | Loss : 0.6233 | Acc: 0.6207 | Sens: 0.9286 | Spec: 0.3333 | F1: 0.7027 | TP: 13 | FP: 10 | FN: 1 | TN: 5
# Epoch 20/50 |  Train | Loss: 1.6346 | Acc: 0.7333 | Sens: 0.6889 | Spec: 0.7778 | F1: 0.7209 | Validate | Loss : 0.5937 | Acc: 0.6522 | Sens: 0.8333 | Spec: 0.4545 | F1: 0.7143 || Final Test | Loss : 0
| Acc: 0.7586 | Sens: 0.9286 | Spec: 0.6000 | F1: 0.7879 | TP: 13 | FP: 6 | FN: 1 | TN: 9
# Epoch 41/50 |  Train | Loss: 1.4922 | Acc: 0.7778 | Sens: 0.6222 | Spec: 0.9333 | F1: 0.7368 | Validate | Loss : 0.5803 | Acc: 0.7391 | Sens: 0.8333 | Spec: 0.6364 | F1: 0.7692 || Final Test | Loss : 0.5657 | Acc: 0.7586 | Sens: 0.9286 | Spec: 0.6000 | F1: 0.7879 | TP: 13 | FP: 6 | FN: 1 | TN: 9
# Epoch 42/50 |  Train | Loss: 1.4598 | Acc: 0.7778 | Sens: 0.7111 | Spec: 0.8444 | F1: 0.7619 | Validate | Loss : 0.5828 | Acc: 0.6522 | Sens: 0.8333 | Spec: 0.4545 | F1: 0.7143 || Final Test | Loss : 0.5682 | Acc: 0.7241 | Sens: 0.9286 | Spec: 0.5333 | F1: 0.7647 | TP: 13 | FP: 7 | FN: 1 | TN: 8
# Epoch 43/50 |  Train | Loss: 1.5423 | Acc: 0.7556 | Sens: 0.8222 | Spec: 0.6889 | F1: 0.7708 | Validate | Loss : 0.5798 | Acc: 0.6087 | Sens: 0.9167 | Spec: 0.2727 | F1: 0.7097 || Final Test | Loss : 0.5616 | Acc: 0.6207 | Sens: 0.9286 | Spec: 0.3333 | F1: 0.7027 | TP: 13 | FP: 10 | FN: 1 | TN: 5
# Epoch 44/50 |  Train | Loss: 1.3655 | Acc: 0.7889 | Sens: 0.6889 | Spec: 0.8889 | F1: 0.7654 | Validate | Loss : 0.5758 | Acc: 0.7391 | Sens: 0.8333 | Spec: 0.6364 | F1: 0.7692 || Final Test | Loss : 0.5531 | Acc: 0.7241 | Sens: 0.8571 | Spec: 0.6000 | F1: 0.7500 | TP: 12 | FP: 6 | FN: 2 | TN: 9
# Epoch 45/50 |  Train | Loss: 1.3870 | Acc: 0.8000 | Sens: 0.7778 | Spec: 0.8222 | F1: 0.7955 | Validate | Loss : 0.5749 | Acc: 0.6957 | Sens: 0.8333 | Spec: 0.5455 | F1: 0.7407 || Final Test | Loss : 0.5485 | Acc: 0.7241 | Sens: 0.9286 | Spec: 0.5333 | F1: 0.7647 | TP: 13 | FP: 7 | FN: 1 | TN: 8
# Epoch 46/50 |  Train | Loss: 1.5035 | Acc: 0.7889 | Sens: 0.6222 | Spec: 0.9556 | F1: 0.7467 | Validate | Loss : 0.5721 | Acc: 0.6957 | Sens: 0.7500 | Spec: 0.6364 | F1: 0.7200 || Final Test | Loss : 0.5414 | Acc: 0.7586 | Sens: 0.8571 | Spec: 0.6667 | F1: 0.7742 | TP: 12 | FP: 5 | FN: 2 | TN: 10
# Epoch 47/50 |  Train | Loss: 1.2503 | Acc: 0.8556 | Sens: 0.7111 | Spec: 1.0000 | F1: 0.8312 | Validate | Loss : 0.5710 | Acc: 0.6957 | Sens: 0.7500 | Spec: 0.6364 | F1: 0.7200 || Final Test | Loss : 0.5377 | Acc: 0.7931 | Sens: 0.8571 | Spec: 0.7333 | F1: 0.8000 | TP: 12 | FP: 4 | FN: 2 | TN: 11
# Epoch 48/50 |  Train | Loss: 1.2878 | Acc: 0.8222 | Sens: 0.8222 | Spec: 0.8222 | F1: 0.8222 | Validate | Loss : 0.5728 | Acc: 0.6087 | Sens: 0.9167 | Spec: 0.2727 | F1: 0.7097 || Final Test | Loss : 0.5372 | Acc: 0.6552 | Sens: 0.9286 | Spec: 0.4000 | F1: 0.7222 | TP: 13 | FP: 9 | FN: 1 | TN: 6
# Epoch 49/50 |  Train | Loss: 1.4242 | Acc: 0.7889 | Sens: 0.7333 | Spec: 0.8444 | F1: 0.7765 | Validate | Loss : 0.5772 | Acc: 0.5652 | Sens: 0.8333 | Spec: 0.2727 | F1: 0.6667 || Final Test | Loss : 0.5457 | Acc: 0.7241 | Sens: 0.9286 | Spec: 0.5333 | F1: 0.7647 | TP: 13 | FP: 7 | FN: 1 | TN: 8
# Epoch 50/50 |  Train | Loss: 1.3610 | Acc: 0.8000 | Sens: 0.6889 | Spec: 0.9111 | F1: 0.7750 | Validate | Loss : 0.5759 | Acc: 0.7391 | Sens: 0.8333 | Spec: 0.6364 | F1: 0.7692 || Final Test | Loss : 0.5428 | Acc: 0.7586 | Sens: 0.9286 | Spec: 0.6000 | F1: 0.7879 | TP: 13 | FP: 6 | FN: 1 | TN: 9
#
# Training on Fold 2...
# Epoch 1/50 |  Train | Loss: 1.6496 | Acc: 0.7667 | Sens: 0.5778 | Spec: 0.9556 | F1: 0.7123 | Validate | Loss : 0.7001 | Acc: 0.6087 | Sens: 0.6667 | Spec: 0.5455 | F1: 0.6400 || Final Test | Loss : 0.5372 | Acc: 0.8276 | Sens: 0.8571 | Spec: 0.8000 | F1: 0.8276 | TP: 12 | FP: 3 | FN: 2 | TN: 12
# Epoch 2/50 |  Train | Loss: 1.4890 | Acc: 0.7444 | Sens: 0.6000 | Spec: 0.8889 | F1: 0.7013 | Validate | Loss : 0.7050 | Acc: 0.5652 | Sens: 0.5833 | Spec: 0.5455 | F1: 0.5833 || Final Test | Loss : 0.5330 | Acc: 0.8621 | Sens: 0.8571 | Spec: 0.8667 | F1: 0.8571 | TP: 12 | FP: 2 | FN: 2 | TN: 13
# Epoch 3/50 |  Train | Loss: 1.5308 | Acc: 0.7556 | Sens: 0.5778 | Spec: 0.9333 | F1: 0.7027 | Validate | Loss : 0.7008 | Acc: 0.6087 | Sens: 0.6667 | Spec: 0.5455 | F1: 0.6400 || Final Test | Loss : 0.5218 | Acc: 0.7931 | Sens: 0.8571 | Spec: 0.7333 | F1: 0.8000 | TP: 12 | FP: 4 | FN: 2 | TN: 11
# Epoch 4/50 |  Train | Loss: 1.4118 | Acc: 0.7778 | Sens: 0.6000 | Spec: 0.9556 | F1: 0.7297 | Validate | Loss : 0.6995 | Acc: 0.6087 | Sens: 0.5833 | Spec: 0.6364 | F1: 0.6087 || Final Test | Loss : 0.5127 | Acc: 0.8621 | Sens: 0.8571 | Spec: 0.8667 | F1: 0.8571 | TP: 12 | FP: 2 | FN: 2 | TN: 13
# Epoch 5/50 |  Train | Loss: 1.3945 | Acc: 0.7889 | Sens: 0.6889 | Spec: 0.8889 | F1: 0.7654 | Validate | Loss : 0.7021 | Acc: 0.6087 | Sens: 0.6667 | Spec: 0.5455 | F1: 0.6400 || Final Test | Loss : 0.5114 | Acc: 0.7931 | Sens: 0.8571 | Spec: 0.7333 | F1: 0.8000 | TP: 12 | FP: 4 | FN: 2 | TN: 11
# Epoch 6/50 |  Train | Loss: 1.5074 | Acc: 0.7778 | Sens: 0.6000 | Spec: 0.9556 | F1: 0.7297 | Validate | Loss : 0.7069 | Acc: 0.6087 | Sens: 0.6667 | Spec: 0.5455 | F1: 0.6400 || Final Test | Loss : 0.5131 | Acc: 0.8276 | Sens: 0.8571 | Spec: 0.8000 | F1: 0.8276 | TP: 12 | FP: 3 | FN: 2 | TN: 12
# Epoch 7/50 |  Train | Loss: 1.3900 | Acc: 0.8000 | Sens: 0.6667 | Spec: 0.9333 | F1: 0.7692 | Validate | Loss : 0.7097 | Acc: 0.6087 | Sens: 0.6667 | Spec: 0.5455 | F1: 0.6400 || Final Test | Loss : 0.5133 | Acc: 0.8276 | Sens: 0.8571 | Spec: 0.8000 | F1: 0.8276 | TP: 12 | FP: 3 | FN: 2 | TN: 12
# Epoch 8/50 |  Train | Loss: 1.4911 | Acc: 0.7667 | Sens: 0.6000 | Spec: 0.9333 | F1: 0.7200 | Validate | Loss : 0.7131 | Acc: 0.5652 | Sens: 0.5833 | Spec: 0.5455 | F1: 0.5833 || Final Test | Loss : 0.5163 | Acc: 0.8276 | Sens: 0.8571 | Spec: 0.8000 | F1: 0.8276 | TP: 12 | FP: 3 | FN: 2 | TN: 12
# Epoch 9/50 |  Train | Loss: 1.4291 | Acc: 0.8000 | Sens: 0.7778 | Spec: 0.8222 | F1: 0.7955 | Validate | Loss : 0.7207 | Acc: 0.6087 | Sens: 0.7500 | Spec: 0.4545 | F1: 0.6667 || Final Test | Loss : 0.5203 | Acc: 0.7586 | Sens: 0.9286 | Spec: 0.6000 | F1: 0.7879 | TP: 13 | FP: 6 | FN: 1 | TN: 9
# Epoch 10/50 |  Train | Loss: 1.3000 | Acc: 0.8000 | Sens: 0.7556 | Spec: 0.8444 | F1: 0.7907 | Validate | Loss : 0.7254 | Acc: 0.6087 | Sens: 0.7500 | Spec: 0.4545 | F1: 0.6667 || Final Test | Loss : 0.5305 | Acc: 0.7586 | Sens: 0.9286 | Spec: 0.6000 | F1: 0.7879 | TP: 13 | FP: 6 | FN: 1 | TN: 9
# Epoch 11/50 |  Train | Loss: 1.2434 | Acc: 0.8333 | Sens: 0.8444 | Spec: 0.8222 | F1: 0.8352 | Validate | Loss : 0.7299 | Acc: 0.6087 | Sens: 0.7500 | Spec: 0.4545 | F1: 0.6667 || Final Test | Loss : 0.
| Acc: 0.8276 | Sens: 0.8571 | Spec: 0.8000 | F1: 0.8276 | TP: 12 | FP: 3 | FN: 2 | TN: 12
# Epoch 50/50 |  Train | Loss: 1.2217 | Acc: 0.8222 | Sens: 0.7391 | Spec: 0.9091 | F1: 0.8095 | Validate | Loss : 0.5143 | Acc: 0.6957 | Sens: 0.8182 | Spec: 0.5833 | F1: 0.7200 || Final Test | Loss : 0.4811 | Acc: 0.7586 | Sens: 0.8571 | Spec: 0.6667 | F1: 0.7742 | TP: 12 | FP: 5 | FN: 2 | TN: 10
#
# Training on Fold 4...
# Epoch 1/50 |  Train | Loss: 1.3188 | Acc: 0.7802 | Sens: 0.7826 | Spec: 0.7778 | F1: 0.7826 | Validate | Loss : 0.5473 | Acc: 0.6818 | Sens: 0.9091 | Spec: 0.4545 | F1: 0.7407 || Final Test | Loss : 0.4936 | Acc: 0.7241 | Sens: 0.9286 | Spec: 0.5333 | F1: 0.7647 | TP: 13 | FP: 7 | FN: 1 | TN: 8
# Epoch 2/50 |  Train | Loss: 1.4177 | Acc: 0.8132 | Sens: 0.7174 | Spec: 0.9111 | F1: 0.7952 | Validate | Loss : 0.5895 | Acc: 0.6818 | Sens: 0.9091 | Spec: 0.4545 | F1: 0.7407 || Final Test | Loss : 0.5185 | Acc: 0.7241 | Sens: 0.9286 | Spec: 0.5333 | F1: 0.7647 | TP: 13 | FP: 7 | FN: 1 | TN: 8
# Epoch 3/50 |  Train | Loss: 1.0903 | Acc: 0.8681 | Sens: 0.7609 | Spec: 0.9778 | F1: 0.8537 | Validate | Loss : 0.6025 | Acc: 0.6818 | Sens: 0.9091 | Spec: 0.4545 | F1: 0.7407 || Final Test | Loss : 0.5274 | Acc: 0.7586 | Sens: 0.8571 | Spec: 0.6667 | F1: 0.7742 | TP: 12 | FP: 5 | FN: 2 | TN: 10
# Epoch 4/50 |  Train | Loss: 1.2760 | Acc: 0.7802 | Sens: 0.6087 | Spec: 0.9556 | F1: 0.7368 | Validate | Loss : 0.6047 | Acc: 0.7727 | Sens: 0.9091 | Spec: 0.6364 | F1: 0.8000 || Final Test | Loss : 0.5278 | Acc: 0.8276 | Sens: 0.8571 | Spec: 0.8000 | F1: 0.8276 | TP: 12 | FP: 3 | FN: 2 | TN: 12
# Epoch 5/50 |  Train | Loss: 1.3698 | Acc: 0.7802 | Sens: 0.6739 | Spec: 0.8889 | F1: 0.7561 | Validate | Loss : 0.6083 | Acc: 0.6818 | Sens: 0.9091 | Spec: 0.4545 | F1: 0.7407 || Final Test | Loss : 0.5288 | Acc: 0.7586 | Sens: 0.9286 | Spec: 0.6000 | F1: 0.7879 | TP: 13 | FP: 6 | FN: 1 | TN: 9
# Epoch 6/50 |  Train | Loss: 1.3133 | Acc: 0.7802 | Sens: 0.6957 | Spec: 0.8667 | F1: 0.7619 | Validate | Loss : 0.6205 | Acc: 0.6818 | Sens: 0.9091 | Spec: 0.4545 | F1: 0.7407 || Final Test | Loss : 0.5345 | Acc: 0.7586 | Sens: 0.8571 | Spec: 0.6667 | F1: 0.7742 | TP: 12 | FP: 5 | FN: 2 | TN: 10
# Epoch 7/50 |  Train | Loss: 1.2239 | Acc: 0.8132 | Sens: 0.6739 | Spec: 0.9556 | F1: 0.7848 | Validate | Loss : 0.6017 | Acc: 0.6818 | Sens: 0.9091 | Spec: 0.4545 | F1: 0.7407 || Final Test | Loss : 0.5195 | Acc: 0.7931 | Sens: 0.8571 | Spec: 0.7333 | F1: 0.8000 | TP: 12 | FP: 4 | FN: 2 | TN: 11
# Epoch 8/50 |  Train | Loss: 1.2710 | Acc: 0.8132 | Sens: 0.7609 | Spec: 0.8667 | F1: 0.8046 | Validate | Loss : 0.6099 | Acc: 0.6818 | Sens: 0.9091 | Spec: 0.4545 | F1: 0.7407 || Final Test | Loss : 0.5208 | Acc: 0.7241 | Sens: 0.9286 | Spec: 0.5333 | F1: 0.7647 | TP: 13 | FP: 7 | FN: 1 | TN: 8
# Epoch 9/50 |  Train | Loss: 1.3157 | Acc: 0.7802 | Sens: 0.6739 | Spec: 0.8889 | F1: 0.7561 | Validate | Loss : 0.5939 | Acc: 0.7273 | Sens: 0.9091 | Spec: 0.5455 | F1: 0.7692 || Final Test | Loss : 0.5086 | Acc: 0.8276 | Sens: 0.8571 | Spec: 0.8000 | F1: 0.8276 | TP: 12 | FP: 3 | FN: 2 | TN: 12
# Epoch 10/50 |  Train | Loss: 1.2962 | Acc: 0.8132 | Sens: 0.7609 | Spec: 0.8667 | F1: 0.8046 | Validate | Loss : 0.5856 | Acc: 0.6818 | Sens: 0.9091 | Spec: 0.4545 | F1: 0.7407 || Final Test | Loss : 0.5011 | Acc: 0.7241 | Sens: 0.9286 | Spec: 0.5333 | F1: 0.7647 | TP: 13 | FP: 7 | FN: 1 | TN: 8
# Epoch 11/50 |  Train | Loss: 1.2939 | Acc: 0.7912 | Sens: 0.8913 | Spec: 0.6889 | F1: 0.8119 | Validate | Loss : 0.5962 | Acc: 0.6818 | Sens: 1.0000 | Spec: 0.3636 | F1: 0.7586 || Final Test | Loss : 0.5038 | Acc: 0.7586 | Sens: 1.0000 | Spec: 0.5333 | F1: 0.8000 | TP: 14 | FP: 7 | FN: 0 | TN: 8
# ...
# Epoch 48/50 |  Train | Loss: 1.2868 | Acc: 0.7912 | Sens: 0.8043 | Spec: 0.7778 | F1: 0.7957 | Validate | Loss : 0.8424 | Acc: 0.6364 | Sens: 1.0000 | Spec: 0.2727 | F1: 0.7333 || Final Test | Loss : 0.6591 | Acc: 0.6207 | Sens: 1.0000 | Spec: 0.2667 | F1: 0.7179 | TP: 14 | FP: 11 | FN: 0 | TN: 4
# Epoch 49/50 |  Train | Loss: 1.0295 | Acc: 0.8462 | Sens: 0.7391 | Spec: 0.9556 | F1: 0.8293 | Validate | Loss : 0.8536 | Acc: 0.6818 | Sens: 1.0000 | Spec: 0.3636 | F1: 0.7586 || Final Test | Loss : 0.6693 | Acc: 0.7586 | Sens: 1.0000 | Spec: 0.5333 | F1: 0.8000 | TP: 14 | FP: 7 | FN: 0 | TN: 8
# Epoch 50/50 |  Train | Loss: 1.4075 | Acc: 0.8132 | Sens: 0.9130 | Spec: 0.7111 | F1: 0.8317 | Validate | Loss : 0.8991 | Acc: 0.5909 | Sens: 1.0000 | Spec: 0.1818 | F1: 0.7097 || Final Test | Loss : 0.7013 | Acc: 0.6207 | Sens: 1.0000 | Spec: 0.2667 | F1: 0.7179 | TP: 14 | FP: 11 | FN: 0 | TN: 4
#
# Training on Fold 5...
# Epoch 1/50 |  Train | Loss: 1.1436 | Acc: 0.8571 | Sens: 0.8261 | Spec: 0.8889 | F1: 0.8539 | Validate | Loss : 0.6399 | Acc: 0.6818 | Sens: 1.0000 | Spec: 0.3636 | F1: 0.7586 || Final Test | Loss : 0.6520 | Acc: 0.6207 | Sens: 1.0000 | Spec: 0.2667 | F1: 0.7179 | TP: 14 | FP: 11 | FN: 0 | TN: 4
# Epoch 2/50 |  Train | Loss: 1.1115 | Acc: 0.8462 | Sens: 0.7391 | Spec: 0.9556 | F1: 0.8293 | Validate | Loss : 0.6390 | Acc: 0.7727 | Sens: 1.0000 | Spec: 0.5455 | F1: 0.8148 || Final Test | Loss : 0.6517 | Acc: 0.7586 | Sens: 1.0000 | Spec: 0.5333 | F1: 0.8000 | TP: 14 | FP: 7 | FN: 0 | TN: 8
# Epoch 3/50 |  Train | Loss: 1.0653 | Acc: 0.8571 | Sens: 0.9130 | Spec: 0.8000 | F1: 0.8660 | Validate | Loss : 0.6461 | Acc: 0.6818 | Sens: 1.0000 | Spec: 0.3636 | F1: 0.7586 || Final Test | Loss : 0.6609 | Acc: 0.6207 | Sens: 1.0000 | Spec: 0.2667 | F1: 0.7179 | TP: 14 | FP: 11 | FN: 0 | TN: 4
# Epoch 4/50 |  Train | Loss: 1.0893 | Acc: 0.8462 | Sens: 0.8261 | Spec: 0.8667 | F1: 0.8444 | Validate | Loss : 0.6242 | Acc: 0.6818 | Sens: 1.0000 | Spec: 0.3636 | F1: 0.7586 || Final Test | Loss : 0.6367 | Acc: 0.6207 | Sens: 1.0000 | Spec: 0.2667 | F1: 0.7179 | TP: 14 | FP: 11 | FN: 0 | TN: 4
# Epoch 5/50 |  Train | Loss: 1.2627 | Acc: 0.7802 | Sens: 0.6739 | Spec: 0.8889 | F1: 0.7561 | Validate | Loss : 0.6318 | Acc: 0.7727 | Sens: 1.0000 | Spec: 0.5455 | F1: 0.8148 || Final Test | Loss : 0.6474 | Acc: 0.7241 | Sens: 1.0000 | Spec: 0.4667 | F1: 0.7778 | TP: 14 | FP: 8 | FN: 0 | TN: 7
# Epoch 6/50 |  Train | Loss: 1.0371 | Acc: 0.8791 | Sens: 0.8913 | Spec: 0.8667 | F1: 0.8817 | Validate | Loss : 0.6219 | Acc: 0.6818 | Sens: 1.0000 | Spec: 0.3636 | F1: 0.7586 || Final Test | Loss : 0.6367 | Acc: 0.6207 | Sens: 1.0000 | Spec: 0.2667 | F1: 0.7179 | TP: 14 | FP: 11 | FN: 0 | TN: 4
# Epoch 7/50 |  Train | Loss: 1.0348 | Acc: 0.8681 | Sens: 0.7609 | Spec: 0.9778 | F1: 0.8537 | Validate | Loss : 0.6309 | Acc: 0.7727 | Sens: 1.0000 | Spec: 0.5455 | F1: 0.8148 || Final Test | Loss : 0.6499 | Acc: 0.6897 | Sens: 1.0000 | Spec: 0.4000 | F1: 0.7568 | TP: 14 | FP: 9 | FN: 0 | TN: 6
# Epoch 8/50 |  Train | Loss: 1.1536 | Acc: 0.8352 | Sens: 0.6957 | Spec: 0.9778 | F1: 0.8101 | Validate | Loss : 0.6174 | Acc: 0.8182 | Sens: 1.0000 | Spec: 0.6364 | F1: 0.8462 || Final Test | Loss : 0.6382 | Acc: 0.7241 | Sens: 0.9286 | Spec: 0.5333 | F1: 0.7647 | TP: 13 | FP: 7 | FN: 1 | TN: 8
# Epoch 9/50 |  Train | Loss: 1.0779 | Acc: 0.8352 | Sens: 0.8478 | Spec: 0.8222 | F1: 0.8387 | Validate | Loss : 0.5939 | Acc: 0.6818 | Sens: 1.0000 | Spec: 0.3636 | F1: 0.7586 || Final Test | Loss : 0.6120 | Acc: 0.6207 | Sens: 1.0000 | Spec: 0.2667 | F1: 0.7179 | TP: 14 | FP: 11 | FN: 0 | TN: 4
# Epoch 10/50 |  Train | Loss: 1.0224 | Acc: 0.8681 | Sens: 0.9130 | Spec: 0.8222 | F1: 0.8750 | Validate | Loss : 0.5798 | Acc: 0.6818 | Sens: 1.0000 | Spec: 0.3636 | F1: 0.7586 || Final Test | Loss : 0.5923 | Acc: 0.6207 | Sens: 1.0000 | Spec: 0.2667 | F1: 0.7179 | TP: 14 | FP: 11 | FN: 0 | TN: 4
# Epoch 11/50 |  Train | Loss: 1.1172 | Acc: 0.8462 | Sens: 0.8696 | Spec: 0.8222 | F1: 0.8511 | Validate | Loss : 0.5810 | Acc: 0.7273 | Sens: 1.0000 | Spec: 0.4545 | F1: 0.7857 || Final Test | Loss : 0.5954 | Acc: 0.6207 | Sens: 1.0000 | Spec: 0.2667 | F1: 0.7179 | TP: 14 | FP: 11 | FN: 0 | TN: 4
# Epoch 12/50 |  Train | Loss: 1.2058 | Acc: 0.8022 | Sens: 0.7826 | Spec: 0.8222 | F1: 0.8000 | Validate | Loss : 0.5785 | Acc: 0.8182 | Sens: 1.0000 | Spec: 0.6364 | F1: 0.8462 || Final Test | Loss : 0.5922 | Acc: 0.7586 | Sens: 1.0000 | Spec: 0.5333 | F1: 0.8000 | TP: 14 | FP: 7 | FN: 0 | TN: 8
# Epoch 13/50 |  Train | Loss: 1.1161 | Acc: 0.8242 | Sens: 0.7609 | Spec: 0.8889 | F1: 0.8140 | Validate | Loss : 0.5726 | Acc: 0.7727 | Sens: 1.0000 | Spec: 0.5455 | F1: 0.8148 || Final Test | Loss : 0.5863 | Acc: 0.6552 | Sens: 1.0000 | Spec: 0.3333 | F1: 0.7368 | TP: 14 | FP: 10 | FN: 0 | TN: 5
# Epoch 14/50 |  Train | Loss: 1.2174 | Acc: 0.8022 | Sens: 0.8043 | Spec: 0.8000 | F1: 0.8043 | Validate | Loss : 0.5737 | Acc: 0.6818 | Sens: 1.0000 | Spec: 0.3636 | F1: 0.7586 || Final Test | Loss : 0.5900 | Acc: 0.6207 | Sens: 1.0000 | Spec: 0.2667 | F1: 0.7179 | TP: 14 | FP: 11 | FN: 0 | TN: 4
# Epoch 15/50 |  Train | Loss: 1.1157 | Acc: 0.8352 | Sens: 0.7826 | Spec: 0.8889 | F1: 0.8276 | Validate | Loss : 0.5789 | Acc: 0.7727 | Sens: 0.9091 | Spec: 0.6364 | F1: 0.8000 || Final Test | Loss : 0.5976 | Acc: 0.7241 | Sens: 0.9286 | Spec: 0.5333 | F1: 0.7647 | TP: 13 | FP: 7 | FN: 1 | TN: 8
# Epoch 16/50 |  Train | Loss: 1.2141 | Acc: 0.8352 | Sens: 0.7609 | Spec: 0.9111 | F1: 0.8235 | Validate | Loss : 0.5931 | Acc: 0.8182 | Sens: 1.0000 | Spec: 0.6364 | F1: 0.8462 || Final Test | Loss : 0.6139 | Acc: 0.7586 | Sens: 1.0000 | Spec: 0.5333 | F1: 0.8000 | TP: 14 | FP: 7 | FN: 0 | TN: 8
# Epoch 17/50 |  Train | Loss: 1.1143 | Acc: 0.8352 | Sens: 0.6957 | Spec: 0.9778 | F1: 0.8101 | Validate | Loss : 0.5913 | Acc: 0.8182 | Sens: 0.9091 | Spec: 0.7273 | F1: 0.8333 || Final Test | Loss : 0.6111 | Acc: 0.7241 | Sens: 0.9286 | Spec: 0.5333 | F1: 0.7647 | TP: 13 | FP: 7 | FN: 1 | TN: 8
# Epoch 18/50 |  Train | Loss: 1.2799 | Acc: 0.8132 | Sens: 0.7609 | Spec: 0.8667 | F1: 0.8046 | Validate | Loss : 0.5869 | Acc: 0.7273 | Sens: 1.0000 | Spec: 0.4545 | F1: 0.7857 || Final Test | Loss : 0.6064 | Acc: 0.6207 | Sens: 1.0000 | Spec: 0.2667 | F1: 0.7179 | TP: 14 | FP: 11 | FN: 0 | TN: 4
# Epoch 19/50 |  Train | Loss: 1.0917 | Acc: 0.8462 | Sens: 0.7826 | Spec: 0.9111 | F1: 0.8372 | Validate | Loss : 0.5969 | Acc: 0.7727 | Sens: 1.0000 | Spec: 0.5455 | F1: 0.8148 || Final Test | Loss : 0.6180 | Acc: 0.6552 | Sens: 1.0000 | Spec: 0.3333 | F1: 0.7368 | TP: 14 | FP: 10 | FN: 0 | TN: 5
# Epoch 20/50 |  Train | Loss: 1.0315 | Acc: 0.8901 | Sens: 0.8261 | Spec: 0.9556 | F1: 0.8837 | Validate | Loss : 0.6017 | Acc: 0.7727 | Sens: 1.0000 | Spec: 0.5455 | F1: 0.8148 || Final Test | Loss : 0.6185 | Acc: 0.6552 | Sens: 1.0000 | Spec: 0.3333 | F1: 0.7368 | TP: 14 | FP: 10 | FN: 0 | TN: 5
# Epoch 21/50 |  Train | Loss: 1.1007 | Acc: 0.8462 | Sens: 0.7391 | Spec: 0.9556 | F1: 0.8293 | Validate | Loss : 0.5979 | Acc: 0.8182 | Sens: 0.9091 | Spec: 0.7273 | F1: 0.8333 || Final Test | Loss : 0.6099 | Acc: 0.7241 | Sens: 0.9286 | Spec: 0.5333 | F1: 0.7647 | TP: 13 | FP: 7 | FN: 1 | TN: 8
# Epoch 22/50 |  Train | Loss: 0.9667 | Acc: 0.8462 | Sens: 0.7174 | Spec: 0.9778 | F1: 0.8250 | Validate | Loss : 0.5878 | Acc: 0.7727 | Sens: 0.9091 | Spec: 0.6364 | F1: 0.8000 || Final Test | Loss : 0.5928 | Acc: 0.7241 | Sens: 0.9286 | Spec: 0.5333 | F1: 0.7647 | TP: 13 | FP: 7 | FN: 1 | TN: 8
# Epoch 23/50 |  Train | Loss: 0.9594 | Acc: 0.8791 | Sens: 0.8043 | Spec: 0.9556 | F1: 0.8706 | Validate | Loss : 0.5862 | Acc: 0.7727 | Sens: 1.0000 | Spec: 0.5455 | F1: 0.8148 || Final Test | Loss : 0.5888 | Acc: 0.7586 | Sens: 1.0000 | Spec: 0.5333 | F1: 0.8000 | TP: 14 | FP: 7 | FN: 0 | TN: 8
# Epoch 24/50 |  Train | Loss: 1.0526 | Acc: 0.8462 | Sens: 0.6957 | Spec: 1.0000 | F1: 0.8205 | Validate | Loss : 0.5866 | Acc: 0.6818 | Sens: 0.6364 | Spec: 0.7273 | F1: 0.6667 || Final Test | Loss : 0.5882 | Acc: 0.7586 | Sens: 0.7857 | Spec: 0.7333 | F1: 0.7586 | TP: 11 | FP: 4 | FN: 3 | TN: 11
# Epoch 25/50 |  Train | Loss: 1.1197 | Acc: 0.8462 | Sens: 0.7174 | Spec: 0.9778 | F1: 0.8250 | Validate | Loss : 0.5805 | Acc: 0.7273 | Sens: 0.7273 | Spec: 0.7273 | F1: 0.7273 || Final Test | Loss : 0.5801 | Acc: 0.6897 | Sens: 0.8571 | Spec: 0.5333 | F1: 0.7273 | TP: 12 | FP: 7 | FN: 2 | TN: 8
# Epoch 26/50 |  Train | Loss: 1.0337 | Acc: 0.8901 | Sens: 0.9348 | Spec: 0.8444 | F1: 0.8958 | Validate | Loss : 0.5845 | Acc: 0.6818 | Sens: 1.0000 | Spec: 0.3636 | F1: 0.7586 || Final Test | Loss : 0.5846 | Acc: 0.6207 | Sens: 1.0000 | Spec: 0.2667 | F1: 0.7179 | TP: 14 | FP: 11 | FN: 0 | TN: 4
# Epoch 27/50 |  Train | Loss: 1.0412 | Acc: 0.8462 | Sens: 0.7826 | Spec: 0.9111 | F1: 0.8372 | Validate | Loss : 0.5711 | Acc: 0.7727 | Sens: 0.9091 | Spec: 0.6364 | F1: 0.8000 || Final Test | Loss : 0.5646 | Acc: 0.7241 | Sens: 0.9286 | Spec: 0.5333 | F1: 0.7647 | TP: 13 | FP: 7 | FN: 1 | TN: 8
# Epoch 28/50 |  Train | Loss: 0.9122 | Acc: 0.8791 | Sens: 0.8913 | Spec: 0.8667 | F1: 0.8817 | Validate | Loss : 0.5683 | Acc: 0.7727 | Sens: 1.0000 | Spec: 0.5455 | F1: 0.8148 || Final Test | Loss : 0.5588 | Acc: 0.6897 | Sens: 0.9286 | Spec: 0.4667 | F1: 0.7429 | TP: 13 | FP: 8 | FN: 1 | TN: 7
# Epoch 29/50 |  Train | Loss: 0.9454 | Acc: 0.8571 | Sens: 0.7391 | Spec: 0.9778 | F1: 0.8395 | Validate | Loss : 0.5622 | Acc: 0.7273 | Sens: 0.7273 | Spec: 0.7273 | F1: 0.7273 || Final Test | Loss : 0.5426 | Acc: 0.7586 | Sens: 0.7857 | Spec: 0.7333 | F1: 0.7586 | TP: 11 | FP: 4 | FN: 3 | TN: 11
# Epoch 30/50 |  Train | Loss: 0.9498 | Acc: 0.8462 | Sens: 0.7826 | Spec: 0.9111 | F1: 0.8372 | Validate | Loss : 0.5649 | Acc: 0.7273 | Sens: 0.8182 | Spec: 0.6364 | F1: 0.7500 || Final Test | Loss : 0.5427 | Acc: 0.7241 | Sens: 0.9286 | Spec: 0.5333 | F1: 0.7647 | TP: 13 | FP: 7 | FN: 1 | TN: 8
# Epoch 31/50 |  Train | Loss: 1.1063 | Acc: 0.8462 | Sens: 0.8478 | Spec: 0.8444 | F1: 0.8478 | Validate | Loss : 0.5664 | Acc: 0.7727 | Sens: 1.0000 | Spec: 0.5455 | F1: 0.8148 || Final Test | Loss : 0.5452 | Acc: 0.6897 | Sens: 0.9286 | Spec: 0.4667 | F1: 0.7429 | TP: 13 | FP: 8 | FN: 1 | TN: 7
# Epoch 32/50 |  Train | Loss: 1.1010 | Acc: 0.8242 | Sens: 0.8043 | Spec: 0.8444 | F1: 0.8222 | Validate | Loss : 0.5674 | Acc: 0.7727 | Sens: 0.9091 | Spec: 0.6364 | F1: 0.8000 || Final Test | Loss : 0.5456 | Acc: 0.7241 | Sens: 0.9286 | Spec: 0.5333 | F1: 0.7647 | TP: 13 | FP: 7 | FN: 1 | TN: 8
# Epoch 33/50 |  Train | Loss: 0.9300 | Acc: 0.8791 | Sens: 0.7826 | Spec: 0.9778 | F1: 0.8675 | Validate | Loss : 0.5626 | Acc: 0.7273 | Sens: 0.7273 | Spec: 0.7273 | F1: 0.7273 || Final Test | Loss : 0.5412 | Acc: 0.6897 | Sens: 0.8571 | Spec: 0.5333 | F1: 0.7273 | TP: 12 | FP: 7 | FN: 2 | TN: 8
# Epoch 34/50 |  Train | Loss: 1.0467 | Acc: 0.8681 | Sens: 0.7391 | Spec: 1.0000 | F1: 0.8500 | Validate | Loss : 0.5611 | Acc: 0.7273 | Sens: 0.7273 | Spec: 0.7273 | F1: 0.7273 || Final Test | Loss : 0.5393 | Acc: 0.6897 | Sens: 0.8571 | Spec: 0.5333 | F1: 0.7273 | TP: 12 | FP: 7 | FN: 2 | TN: 8
# Epoch 35/50 |  Train | Loss: 0.9530 | Acc: 0.8571 | Sens: 0.7391 | Spec: 0.9778 | F1: 0.8395 | Validate | Loss : 0.5610 | Acc: 0.7273 | Sens: 0.7273 | Spec: 0.7273 | F1: 0.7273 || Final Test | Loss : 0.5411 | Acc: 0.7586 | Sens: 0.7857 | Spec: 0.7333 | F1: 0.7586 | TP: 11 | FP: 4 | FN: 3 | TN: 11
# Epoch 36/50 |  Train | Loss: 0.9793 | Acc: 0.8681 | Sens: 0.8043 | Spec: 0.9333 | F1: 0.8605 | Validate | Loss : 0.5685 | Acc: 0.7273 | Sens: 0.8182 | Spec: 0.6364 | F1: 0.7500 || Final Test | Loss : 0.5503 | Acc: 0.7241 | Sens: 0.9286 | Spec: 0.5333 | F1: 0.7647 | TP: 13 | FP: 7 | FN: 1 | TN: 8
# Epoch 37/50 |  Train | Loss: 0.9811 | Acc: 0.8571 | Sens: 0.7174 | Spec: 1.0000 | F1: 0.8354 | Validate | Loss : 0.5691 | Acc: 0.7273 | Sens: 0.7273 | Spec: 0.7273 | F1: 0.7273 || Final Test | Loss : 0.
# Epoch 46/50 |  Train | Loss: 1.1293 | Acc: 0.8462 | Sens: 0.7174 | Spec: 0.9778 | F1: 0.8250 | Validate | Loss : 0.5442 | Acc: 0.5909 | Sens: 0.4545 | Spec: 0.7273 | F1: 0.5263 || Final Test | Loss : 0.4913 | Acc: 0.8276 | Sens: 0.7143 | Spec: 0.9333 | F1: 0.8000 | TP: 10 | FP: 1 | FN: 4 | TN: 14
# Epoch 47/50 |  Train | Loss: 1.0445 | Acc: 0.8462 | Sens: 0.9565 | Spec: 0.7333 | F1: 0.8627 | Validate | Loss : 0.5433 | Acc: 0.8636 | Sens: 1.0000 | Spec: 0.7273 | F1: 0.8800 || Final Test | Loss : 0.4950 | Acc: 0.6897 | Sens: 1.0000 | Spec: 0.4000 | F1: 0.7568 | TP: 14 | FP: 9 | FN: 0 | TN: 6
# Epoch 48/50 |  Train | Loss: 0.8991 | Acc: 0.8901 | Sens: 0.8478 | Spec: 0.9333 | F1: 0.8864 | Validate | Loss : 0.5414 | Acc: 0.7273 | Sens: 0.7273 | Spec: 0.7273 | F1: 0.7273 || Final Test | Loss : 0.4987 | Acc: 0.7241 | Sens: 0.7857 | Spec: 0.6667 | F1: 0.7333 | TP: 11 | FP: 5 | FN: 3 | TN: 10
# Epoch 49/50 |  Train | Loss: 1.1053 | Acc: 0.8352 | Sens: 0.8261 | Spec: 0.8444 | F1: 0.8352 | Validate | Loss : 0.5432 | Acc: 0.7727 | Sens: 0.8182 | Spec: 0.7273 | F1: 0.7826 || Final Test | Loss : 0.5078 | Acc: 0.6897 | Sens: 0.8571 | Spec: 0.5333 | F1: 0.7273 | TP: 12 | FP: 7 | FN: 2 | TN: 8
# Epoch 50/50 |  Train | Loss: 0.9134 | Acc: 0.8681 | Sens: 0.7391 | Spec: 1.0000 | F1: 0.8500 | Validate | Loss : 0.5487 | Acc: 0.6364 | Sens: 0.5455 | Spec: 0.7273 | F1: 0.6000 || Final Test | Loss : 0.5171 | Acc: 0.7586 | Sens: 0.7857 | Spec: 0.7333 | F1: 0.7586 | TP: 11 | FP: 4 | FN: 3 | TN: 11

# %%
# import torch

# # Flatten images for easier comparison
# X_train_tensor = fold_data["X_train"].reshape(fold_data["X_train"].shape[0], -1)  # (N, Flattened)
# X_test_tensor = fold_data["X_test"].reshape(fold_data["X_test"].shape[0], -1)  # (M, Flattened)

# #  Use broadcasting for efficient comparison
# tolerance = 1e-6  # Allow small differences due to floating point precision
# matches = (torch.abs(X_test_tensor.unsqueeze(1) - X_train_tensor) < tolerance).all(dim=2)

# #  Count duplicates
# overlapping_samples = matches.any(dim=1).sum().item()

# #  Print the number of overlapping images
# if overlapping_samples > 0:
#     print(f"⚠ WARNING: {overlapping_samples} test images are nearly identical to training images! Possible data leakage detected!")
# else:
#     print(" No identical test images found in the training set. No data leakage detected.")

# %%
# test_duplicates = matches.any(dim=1).sum().item()
# print(f"Test Images Detected as Duplicates: {test_duplicates}")

# # If duplicates exist, print a few to inspect manually
# duplicate_indices = torch.where(matches.any(dim=1))[0].cpu().numpy()
# for idx in duplicate_indices[:5]:  # Show first few duplicates
#     print(f"Test Image {idx} matches a training image.")

# %%
# import torch

# # Find training indices where the matches occur
# matching_train_indices = torch.where(matches)[1].cpu().numpy()  # Get training image indices

# # Print which training images match each duplicated test image
# for test_idx, train_idx in zip(duplicate_indices, matching_train_indices):
#     print(f"Test Image {test_idx} is identical to Training Image {train_idx}.")

# %%
# CHECK FOR DUPLICATES IN ORIGINAL DATASET

# Define a transformation to resize images and convert to tensor
# transform = transforms.Compose([
#     transforms.Resize((224, 224)),  # Resize to 224x224 (DINOv2 input size)
#     transforms.ToTensor(),  # Convert to tensor
# ])

# # Function to load all images from a folder
# def load_images_from_folder(folder):
#     images = []
#     image_filenames = []

#     for filename in os.listdir(folder):
#         file_path = os.path.join(folder, filename)
#         if filename.lower().endswith(('.png', '.jpg', '.jpeg')):  # Ensure it's an image
#             try:
#                 img = Image.open(file_path).convert("RGB")  # Ensure 3-channel RGB
#                 img_tensor = transform(img)  # Apply transformations
#                 images.append(img_tensor)
#                 image_filenames.append(filename)  # Store filenames for debugging
#             except Exception as e:
#                 print(f"Error loading {filename}: {e}")

#     return images, image_filenames

# # Load images from both classes
# healthy_images, healthy_filenames = load_images_from_folder(healthy_path)
# sick_images, sick_filenames = load_images_from_folder(sick_path)

# # Combine into a full dataset
# full_images = healthy_images + sick_images
# full_filenames = healthy_filenames + sick_filenames  # Keep filenames for debugging

# print(f"Total images loaded: {len(full_images)}")
# #  Step 2: Convert Images to Hashes for Duplicate Detection
# # Now that we have loaded all images as tensors, we can check for duplicates by hashing each image.

# # python
# # Copy

# def hash_image(image_tensor):
#     """Generate a hash for an image tensor to detect duplicates."""
#     return hashlib.md5(image_tensor.numpy().tobytes()).hexdigest()

# # Generate hashes for all images
# image_hashes = [hash_image(img) for img in full_images]

# # Find duplicates
# hash_counts = {}
# duplicates = []

# for i, hash_value in enumerate(image_hashes):
#     if hash_value in hash_counts:
#         duplicates.append((full_filenames[i], full_filenames[hash_counts[hash_value]]))  # Store duplicate filenames
#     else:
#         hash_counts[hash_value] = i

# # Print duplicate results
# if duplicates:
#     print(f"⚠ Found {len(duplicates)} duplicate images!")
#     for dup1, dup2 in duplicates:
#         print(f"Duplicate: {dup1} and {dup2}")
# else:
#     print(" No duplicates found before splitting.")
# def hash_image(image_tensor):
#     """Generate a hash for an image tensor to detect duplicates."""
#     return hashlib.md5(image_tensor.numpy().tobytes()).hexdigest()

# # Generate hashes for all images
# image_hashes = [hash_image(img) for img in full_images]

# # Find duplicates
# hash_counts = {}
# duplicates = []

# for i, hash_value in enumerate(image_hashes):
#     if hash_value in hash_counts:
#         duplicates.append((full_filenames[i], full_filenames[hash_counts[hash_value]]))  # Store duplicate filenames
#     else:
#         hash_counts[hash_value] = i

# # Print duplicate results
# if duplicates:
#     print(f"⚠ Found {len(duplicates)} duplicate images!")
#     for dup1, dup2 in duplicates:
#         print(f"Duplicate: {dup1} and {dup2}")
# else:
#     print(" No duplicates found before splitting.")
